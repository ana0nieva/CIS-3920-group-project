# %% [markdown]
# # Import the necessary libraries, read csv file, merge movies and credits table

# %%
import pandas as pd
import numpy as np
import nltk
import string
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
from nltk.stem import LancasterStemmer
from nltk.stem import WordNetLemmatizer
import re
import warnings
import operator
import collections
! pip install rake_nltk
from rake_nltk import Rake
warnings.filterwarnings("ignore", category=DeprecationWarning)
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# Collecting rake_nltk
#   Downloading rake_nltk-1.0.6-py3-none-any.whl (9.1 kB)
# Requirement already satisfied: nltk<4.0.0,>=3.6.2 in c:\users\mbegu\anaconda3\lib\site-packages (from rake_nltk) (3.7)
# Requirement already satisfied: tqdm in c:\users\mbegu\anaconda3\lib\site-packages (from nltk<4.0.0,>=3.6.2->rake_nltk) (4.64.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\mbegu\anaconda3\lib\site-packages (from nltk<4.0.0,>=3.6.2->rake_nltk) (2022.3.15)
# Requirement already satisfied: click in c:\users\mbegu\anaconda3\lib\site-packages (from nltk<4.0.0,>=3.6.2->rake_nltk) (8.0.4)
# Requirement already satisfied: joblib in c:\users\mbegu\anaconda3\lib\site-packages (from nltk<4.0.0,>=3.6.2->rake_nltk) (1.1.0)
# Requirement already satisfied: colorama in c:\users\mbegu\anaconda3\lib\site-packages (from click->nltk<4.0.0,>=3.6.2->rake_nltk) (0.4.4)
# Installing collected packages: rake-nltk
# Successfully installed rake-nltk-1.0.6
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\mbegu\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\mbegu\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
movies=pd.read_csv('tmdb_5000_movies.csv')
credits=pd.read_csv('tmdb_5000_credits.csv')

# %%
credits.columns=['id','title','cast','crew']
movies_merge=movies.merge(credits, on='id')

# %%
movies_merge.head(3)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
#
#                                 production_companies  ... runtime  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...  ...   162.0
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...  ...   169.0
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...  ...   148.0
#
#                                     spoken_languages    status  \
# 0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1           [{"iso_639_1": "en", "name": "English"}]  Released
# 2  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
#
#                                     title_x vote_average vote_count  \
# 0                                    Avatar          7.2      11800
# 1  Pirates of the Caribbean: At World's End          6.9       4500
# 2                                   Spectre          6.3       4466
#
#                                     title_y  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
#
# [3 rows x 23 columns]

# %%
movies_df= pd.DataFrame(movies_merge[['id','popularity','keywords','homepage','original_title','budget','revenue','genres', 'overview', 'cast', 'tagline']])
movies_df.head(3)
# Out:
#        id  popularity                                           keywords  \
# 0   19995  150.437577  [{"id": 1463, "name": "culture clash"}, {"id":...
# 1     285  139.082615  [{"id": 270, "name": "ocean"}, {"id": 726, "na...
# 2  206647  107.376788  [{"id": 470, "name": "spy"}, {"id": 818, "name...
#
#                                        homepage  \
# 0                   http://www.avatarmovie.com/
# 1  http://disney.go.com/disneypictures/pirates/
# 2   http://www.sonypictures.com/movies/spectre/
#
#                              original_title     budget     revenue  \
# 0                                    Avatar  237000000  2787965087
# 1  Pirates of the Caribbean: At World's End  300000000   961000000
# 2                                   Spectre  245000000   880674609
#
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
#
#                                           tagline
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes

# %%
movies_df.fillna('', inplace = True)

# %% [markdown]
# # Split keywords and overview into their own dataframes for text cleaning

# %%
keywords_df = movies_df[['keywords']]
keywords_df.to_csv('keywords.csv', index=False)
keywords=pd.read_csv('keywords.csv')
keywords.head(4)
# Out:
#                                             keywords
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...

# %%
overview_df = movies_df[['overview']]
overview_df.to_csv('overview.csv', index=False)
overview_df=pd.read_csv('overview.csv')
overview_df.head(4)
# Out:
#                                             overview
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...

# %% [markdown]
# # Text cleaning keywords: remove punctutation, then tokenize and lowercase

# %%
# Display punctuation symbols
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
# Create function to remove punctuation
def remove_punct(text):
    text_nopunct = "".join([char for char in text if char not in string.punctuation])
    return text_nopunct

# Remove punctuation from data
keywords_df['keywords_w/o_punct'] = keywords_df['keywords'].apply(lambda x: remove_punct(x))
keywords_df.head()
# Out:
# C:\Users\mbegu\AppData\Local\Temp\ipykernel_11040\760405889.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   keywords_df['keywords_w/o_punct'] = keywords_df['keywords'].apply(lambda x: remove_punct(x))
#                                             keywords  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...
# 4  [{"id": 818, "name": "based on novel"}, {"id":...
#
#                                   keywords_w/o_punct
# 0  id 1463 name culture clash id 2964 name future...
# 1  id 270 name ocean id 726 name drug abuse id 91...
# 2  id 470 name spy id 818 name based on novel id ...
# 3  id 849 name dc comics id 853 name crime fighte...
# 4  id 818 name based on novel id 839 name mars id...

# %%
# Create function to tokenize and lowercase data
def tokenize(text):
    # W+ means that either a word character (A-Za-z0-9_) or a dash (-) can go there.
    tokens = re.split('\W+', text)
    return tokens

# Tokenize and lowercase data 
keywords_df['tokenized_keywords'] = keywords_df['keywords_w/o_punct'].apply(lambda x: tokenize(x.lower())) 
keywords_df.head()
# Out:
# C:\Users\mbegu\AppData\Local\Temp\ipykernel_11040\2484443038.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   keywords_df['tokenized_keywords'] = keywords_df['keywords_w/o_punct'].apply(lambda x: tokenize(x.lower()))
#                                             keywords  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...
# 4  [{"id": 818, "name": "based on novel"}, {"id":...
#
#                                   keywords_w/o_punct  \
# 0  id 1463 name culture clash id 2964 name future...
# 1  id 270 name ocean id 726 name drug abuse id 91...
# 2  id 470 name spy id 818 name based on novel id ...
# 3  id 849 name dc comics id 853 name crime fighte...
# 4  id 818 name based on novel id 839 name mars id...
#
#                                   tokenized_keywords
# 0  [id, 1463, name, culture, clash, id, 2964, nam...
# 1  [id, 270, name, ocean, id, 726, name, drug, ab...
# 2  [id, 470, name, spy, id, 818, name, based, on,...
# 3  [id, 849, name, dc, comics, id, 853, name, cri...
# 4  [id, 818, name, based, on, novel, id, 839, nam...

# %% [markdown]
# # Text cleaning overview: remove punctutation, tokenize and lowercase, stem, and remove stopwords

# %%
overview_df.fillna('', inplace = True)

# %%
# Remove punctuation from data
overview_df['overview_w/o_punct'] = overview_df['overview'].apply(lambda x: remove_punct(x))
overview_df.head()
# Out:
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                   overview_w/o_punct
# 0  In the 22nd century a paraplegic Marine is dis...
# 1  Captain Barbossa long believed to be dead has ...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a warweary former military capt...

# %%
# Tokenize and lowercase data 
overview_df['tokenized_overview'] = overview_df['overview_w/o_punct'].apply(lambda x: tokenize(x.lower())) 
overview_df.head()
# Out:
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                   overview_w/o_punct  \
# 0  In the 22nd century a paraplegic Marine is dis...
# 1  Captain Barbossa long believed to be dead has ...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a warweary former military capt...
#
#                                   tokenized_overview
# 0  [in, the, 22nd, century, a, paraplegic, marine...
# 1  [captain, barbossa, long, believed, to, be, de...
# 2  [a, cryptic, message, from, bond, s, past, sen...
# 3  [following, the, death, of, district, attorney...
# 4  [john, carter, is, a, warweary, former, milita...

# %%
# Define stop words list
stopwords = nltk.corpus.stopwords.words('english')     # All English Stopwords
stopwords
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
# Create function to remove stopwords
def remove_stopwords(tokenized_list):
    text = [word for word in tokenized_list if word not in stopwords]
    return text

# Remove stop words from data
overview_df['stopwords_overview'] = overview_df['tokenized_overview'].apply(lambda x: remove_stopwords(x))
overview_df.head()
# Out:
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                   overview_w/o_punct  \
# 0  In the 22nd century a paraplegic Marine is dis...
# 1  Captain Barbossa long believed to be dead has ...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a warweary former military capt...
#
#                                   tokenized_overview  \
# 0  [in, the, 22nd, century, a, paraplegic, marine...
# 1  [captain, barbossa, long, believed, to, be, de...
# 2  [a, cryptic, message, from, bond, s, past, sen...
# 3  [following, the, death, of, district, attorney...
# 4  [john, carter, is, a, warweary, former, milita...
#
#                                   stopwords_overview
# 0  [22nd, century, paraplegic, marine, dispatched...
# 1  [captain, barbossa, long, believed, dead, come...
# 2  [cryptic, message, bond, past, sends, trail, u...
# 3  [following, death, district, attorney, harvey,...
# 4  [john, carter, warweary, former, military, cap...

# %%
ps = nltk.PorterStemmer()

# Create function to apply stemmer
def stemming(tokenized_text):
    text = [ps.stem(word) for word in tokenized_text]
    return text

# Apply Porter Stemmer
overview_df['stemmed_overview'] = overview_df['stopwords_overview'].apply(lambda x: stemming(x))
overview_df.head()
# Out:
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                   overview_w/o_punct  \
# 0  In the 22nd century a paraplegic Marine is dis...
# 1  Captain Barbossa long believed to be dead has ...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a warweary former military capt...
#
#                                   tokenized_overview  \
# 0  [in, the, 22nd, century, a, paraplegic, marine...
# 1  [captain, barbossa, long, believed, to, be, de...
# 2  [a, cryptic, message, from, bond, s, past, sen...
# 3  [following, the, death, of, district, attorney...
# 4  [john, carter, is, a, warweary, former, milita...
#
#                                   stopwords_overview  \
# 0  [22nd, century, paraplegic, marine, dispatched...
# 1  [captain, barbossa, long, believed, dead, come...
# 2  [cryptic, message, bond, past, sends, trail, u...
# 3  [following, death, district, attorney, harvey,...
# 4  [john, carter, warweary, former, military, cap...
#
#                                     stemmed_overview
# 0  [22nd, centuri, parapleg, marin, dispatch, moo...
# 1  [captain, barbossa, long, believ, dead, come, ...
# 2  [cryptic, messag, bond, past, send, trail, unc...
# 3  [follow, death, district, attorney, harvey, de...
# 4  [john, carter, warweari, former, militari, cap...

# %% [markdown]
# # Getting keywords from overview + merge with the keywords column to recreate the keywords column

# %%
# Create function to extract
def extract_key_words(input_str):
    r = Rake()
    r.extract_keywords_from_text(input_str.lower())
    key_words_dict_scores = r.get_word_degrees()
    sorted_key_words_dict_scores = sorted(key_words_dict_scores.items(), key=operator.itemgetter(1), reverse=True)
    sorted_dict = collections.OrderedDict(sorted_key_words_dict_scores)
#    return sorted_dict, list(sorted_dict.keys())[:round(len(sorted_dict.keys())/2)]
    return sorted_dict, list(sorted_dict.keys())[:5] # 5 is the number of the highest rated keywords returned
                                                         #  Change this value as you wish

# %%
overview_df['overview_keywords'] = overview_df['overview'].apply(lambda x: extract_key_words(x)[1]).apply(' '.join)
overview_df.head()
# Out:
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                   overview_w/o_punct  \
# 0  In the 22nd century a paraplegic Marine is dis...
# 1  Captain Barbossa long believed to be dead has ...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a warweary former military capt...
#
#                                   tokenized_overview  \
# 0  [in, the, 22nd, century, a, paraplegic, marine...
# 1  [captain, barbossa, long, believed, to, be, de...
# 2  [a, cryptic, message, from, bond, s, past, sen...
# 3  [following, the, death, of, district, attorney...
# 4  [john, carter, is, a, warweary, former, milita...
#
#                                   stopwords_overview  \
# 0  [22nd, century, paraplegic, marine, dispatched...
# 1  [captain, barbossa, long, believed, dead, come...
# 2  [cryptic, message, bond, past, sends, trail, u...
# 3  [following, death, district, attorney, harvey,...
# 4  [john, carter, warweary, former, military, cap...
#
#                                     stemmed_overview  \
# 0  [22nd, centuri, parapleg, marin, dispatch, moo...
# 1  [captain, barbossa, long, believ, dead, come, ...
# 2  [cryptic, messag, bond, past, send, trail, unc...
# 3  [follow, death, district, attorney, harvey, de...
# 4  [john, carter, warweari, former, militari, cap...
#
#                             overview_keywords
# 0         22nd century paraplegic marine moon
# 1         captain barbossa long believed come
# 2          bond terrible truth behind spectre
# 3            attorney gotham dent batman city
# 4  carter former military captain reluctantly

# %%
overview_df['overviewv2'] = overview_df['overview_keywords'].apply(lambda x: tokenize(x.lower())) 
overview_df.head()
# Out:
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                   overview_w/o_punct  \
# 0  In the 22nd century a paraplegic Marine is dis...
# 1  Captain Barbossa long believed to be dead has ...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a warweary former military capt...
#
#                                   tokenized_overview  \
# 0  [in, the, 22nd, century, a, paraplegic, marine...
# 1  [captain, barbossa, long, believed, to, be, de...
# 2  [a, cryptic, message, from, bond, s, past, sen...
# 3  [following, the, death, of, district, attorney...
# 4  [john, carter, is, a, warweary, former, milita...
#
#                                   stopwords_overview  \
# 0  [22nd, century, paraplegic, marine, dispatched...
# 1  [captain, barbossa, long, believed, dead, come...
# 2  [cryptic, message, bond, past, sends, trail, u...
# 3  [following, death, district, attorney, harvey,...
# 4  [john, carter, warweary, former, military, cap...
#
#                                     stemmed_overview  \
# 0  [22nd, centuri, parapleg, marin, dispatch, moo...
# 1  [captain, barbossa, long, believ, dead, come, ...
# 2  [cryptic, messag, bond, past, send, trail, unc...
# 3  [follow, death, district, attorney, harvey, de...
# 4  [john, carter, warweari, former, militari, cap...
#
#                             overview_keywords  \
# 0         22nd century paraplegic marine moon
# 1         captain barbossa long believed come
# 2          bond terrible truth behind spectre
# 3            attorney gotham dent batman city
# 4  carter former military captain reluctantly
#
#                                          overviewv2
# 0         [22nd, century, paraplegic, marine, moon]
# 1         [captain, barbossa, long, believed, come]
# 2          [bond, terrible, truth, behind, spectre]
# 3            [attorney, gotham, dent, batman, city]
# 4  [carter, former, military, captain, reluctantly]

# %%
overview_df['overviewv2'] = overview_df['overviewv2'].astype("string")
overview_df
# Out:
#                                                overview  \
# 0     In the 22nd century, a paraplegic Marine is di...
# 1     Captain Barbossa, long believed to be dead, ha...
# 2     A cryptic message from Bond’s past sends him o...
# 3     Following the death of District Attorney Harve...
# 4     John Carter is a war-weary, former military ca...
# ...                                                 ...
# 4797  El Mariachi just wants to play his guitar and ...
# 4798  A newlywed couple's honeymoon is upended by th...
# 4799  "Signed, Sealed, Delivered" introduces a dedic...
# 4800  When ambitious New York attorney Sam is sent t...
# 4801  Ever since the second grade when he first saw ...
#
#                                      overview_w/o_punct  \
# 0     In the 22nd century a paraplegic Marine is dis...
# 1     Captain Barbossa long believed to be dead has ...
# 2     A cryptic message from Bond’s past sends him o...
# 3     Following the death of District Attorney Harve...
# 4     John Carter is a warweary former military capt...
# ...                                                 ...
# 4797  El Mariachi just wants to play his guitar and ...
# 4798  A newlywed couples honeymoon is upended by the...
# 4799  Signed Sealed Delivered introduces a dedicated...
# 4800  When ambitious New York attorney Sam is sent t...
# 4801  Ever since the second grade when he first saw ...
#
#                                      tokenized_overview  \
# 0     [in, the, 22nd, century, a, paraplegic, marine...
# 1     [captain, barbossa, long, believed, to, be, de...
# 2     [a, cryptic, message, from, bond, s, past, sen...
# 3     [following, the, death, of, district, attorney...
# 4     [john, carter, is, a, warweary, former, milita...
# ...                                                 ...
# 4797  [el, mariachi, just, wants, to, play, his, gui...
# 4798  [a, newlywed, couples, honeymoon, is, upended,...
# 4799  [signed, sealed, delivered, introduces, a, ded...
# 4800  [when, ambitious, new, york, attorney, sam, is...
# 4801  [ever, since, the, second, grade, when, he, fi...
#
#                                      stopwords_overview  \
# 0     [22nd, century, paraplegic, marine, dispatched...
# 1     [captain, barbossa, long, believed, dead, come...
# 2     [cryptic, message, bond, past, sends, trail, u...
# 3     [following, death, district, attorney, harvey,...
# 4     [john, carter, warweary, former, military, cap...
# ...                                                 ...
# 4797  [el, mariachi, wants, play, guitar, carry, fam...
# 4798  [newlywed, couples, honeymoon, upended, arriva...
# 4799  [signed, sealed, delivered, introduces, dedica...
# 4800  [ambitious, new, york, attorney, sam, sent, sh...
# 4801  [ever, since, second, grade, first, saw, et, e...
#
#                                        stemmed_overview  \
# 0     [22nd, centuri, parapleg, marin, dispatch, moo...
# 1     [captain, barbossa, long, believ, dead, come, ...
# 2     [cryptic, messag, bond, past, send, trail, unc...
# 3     [follow, death, district, attorney, harvey, de...
# 4     [john, carter, warweari, former, militari, cap...
# ...                                                 ...
# 4797  [el, mariachi, want, play, guitar, carri, fami...
# 4798  [newlyw, coupl, honeymoon, upend, arriv, respe...
# 4799  [sign, seal, deliv, introduc, dedic, quartet, ...
# 4800  [ambiti, new, york, attorney, sam, sent, shang...
# 4801  [ever, sinc, second, grade, first, saw, et, ex...
#
#                                  overview_keywords  \
# 0              22nd century paraplegic marine moon
# 1              captain barbossa long believed come
# 2               bond terrible truth behind spectre
# 3                 attorney gotham dent batman city
# 4       carter former military captain reluctantly
# ...                                            ...
# 4797                  el mariachi guitar town case
# 4798  newlywed couple respective sisters honeymoon
# 4799    office dead letter seemingly undeliverable
# 4800               sam ambitious new york attorney
# 4801            brian herzlinger drew barrymore 20
#
#                                              overviewv2
# 0     ['22nd', 'century', 'paraplegic', 'marine', 'm...
# 1     ['captain', 'barbossa', 'long', 'believed', 'c...
# 2     ['bond', 'terrible', 'truth', 'behind', 'spect...
# 3      ['attorney', 'gotham', 'dent', 'batman', 'city']
# 4     ['carter', 'former', 'military', 'captain', 'r...
# ...                                                 ...
# 4797       ['el', 'mariachi', 'guitar', 'town', 'case']
# 4798  ['newlywed', 'couple', 'respective', 'sisters'...
# 4799  ['office', 'dead', 'letter', 'seemingly', 'und...
# 4800    ['sam', 'ambitious', 'new', 'york', 'attorney']
# 4801  ['brian', 'herzlinger', 'drew', 'barrymore', '...
#
# [4802 rows x 7 columns]

# %%
import json

# %%
MKeyword = keywords_df['keywords']
names4 = []
for movie in MKeyword:
    submovie = []
    movie = json.loads(movie)
    for attribute in movie: 
        submovie.append(attribute["name"])
    names4.append(submovie)
    for x in names4:
        json.dumps(x)

# %%
keywords_df.insert(3, 'keywordsv2', names4, True)

# %%
keywords_df['keywordsv2'] = keywords_df['keywordsv2'].astype("string")
keywords_df
# Out:
# C:\Users\mbegu\AppData\Local\Temp\ipykernel_11040\1435373397.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   keywords_df['keywordsv2'] = keywords_df['keywordsv2'].astype("string")
#                                                keywords  \
# 0     [{"id": 1463, "name": "culture clash"}, {"id":...
# 1     [{"id": 270, "name": "ocean"}, {"id": 726, "na...
# 2     [{"id": 470, "name": "spy"}, {"id": 818, "name...
# 3     [{"id": 849, "name": "dc comics"}, {"id": 853,...
# 4     [{"id": 818, "name": "based on novel"}, {"id":...
# ...                                                 ...
# 4798  [{"id": 5616, "name": "united states\u2013mexi...
# 4799                                                 []
# 4800  [{"id": 248, "name": "date"}, {"id": 699, "nam...
# 4801                                                 []
# 4802  [{"id": 1523, "name": "obsession"}, {"id": 224...
#
#                                      keywords_w/o_punct  \
# 0     id 1463 name culture clash id 2964 name future...
# 1     id 270 name ocean id 726 name drug abuse id 91...
# 2     id 470 name spy id 818 name based on novel id ...
# 3     id 849 name dc comics id 853 name crime fighte...
# 4     id 818 name based on novel id 839 name mars id...
# ...                                                 ...
# 4798  id 5616 name united statesu2013mexico barrier ...
# 4799
# 4800  id 248 name date id 699 name love at first sig...
# 4801
# 4802  id 1523 name obsession id 2249 name camcorder ...
#
#                                      tokenized_keywords  \
# 0     [id, 1463, name, culture, clash, id, 2964, nam...
# 1     [id, 270, name, ocean, id, 726, name, drug, ab...
# 2     [id, 470, name, spy, id, 818, name, based, on,...
# 3     [id, 849, name, dc, comics, id, 853, name, cri...
# 4     [id, 818, name, based, on, novel, id, 839, nam...
# ...                                                 ...
# 4798  [id, 5616, name, united, statesu2013mexico, ba...
# 4799                                                 []
# 4800  [id, 248, name, date, id, 699, name, love, at,...
# 4801                                                 []
# 4802  [id, 1523, name, obsession, id, 2249, name, ca...
#
#                                              keywordsv2
# 0     ['culture clash', 'future', 'space war', 'spac...
# 1     ['ocean', 'drug abuse', 'exotic island', 'east...
# 2     ['spy', 'based on novel', 'secret agent', 'seq...
# 3     ['dc comics', 'crime fighter', 'terrorist', 's...
# 4     ['based on novel', 'mars', 'medallion', 'space...
# ...                                                 ...
# 4798  ['united states–mexico barrier', 'legs', 'arms...
# 4799                                                 []
# 4800  ['date', 'love at first sight', 'narration', '...
# 4801                                                 []
# 4802  ['obsession', 'camcorder', 'crush', 'dream girl']
#
# [4803 rows x 4 columns]

# %%
movies_df.drop(columns='keywords', inplace=True)
movies_df
# Out:
#           id  popularity                                           homepage  \
# 0      19995  150.437577                        http://www.avatarmovie.com/
# 1        285  139.082615       http://disney.go.com/disneypictures/pirates/
# 2     206647  107.376788        http://www.sonypictures.com/movies/spectre/
# 3      49026  112.312950                 http://www.thedarkknightrises.com/
# 4      49529   43.926995               http://movies.disney.com/john-carter
# ...      ...         ...                                                ...
# 4798    9367   14.269792
# 4799   72766    0.642552
# 4800  231617    1.444476  http://www.hallmarkchannel.com/signedsealeddel...
# 4801  126186    0.857008                        http://shanghaicalling.com/
# 4802   25975    1.929883
#
#                                 original_title     budget     revenue  \
# 0                                       Avatar  237000000  2787965087
# 1     Pirates of the Caribbean: At World's End  300000000   961000000
# 2                                      Spectre  245000000   880674609
# 3                        The Dark Knight Rises  250000000  1084939099
# 4                                  John Carter  260000000   284139100
# ...                                        ...        ...         ...
# 4798                               El Mariachi     220000     2040920
# 4799                                 Newlyweds       9000           0
# 4800                 Signed, Sealed, Delivered          0           0
# 4801                          Shanghai Calling          0           0
# 4802                         My Date with Drew          0           0
#
#                                                  genres  \
# 0     [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...                                                 ...
# 4798  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801                                                 []
# 4802                [{"id": 99, "name": "Documentary"}]
#
#                                                overview  \
# 0     In the 22nd century, a paraplegic Marine is di...
# 1     Captain Barbossa, long believed to be dead, ha...
# 2     A cryptic message from Bond’s past sends him o...
# 3     Following the death of District Attorney Harve...
# 4     John Carter is a war-weary, former military ca...
# ...                                                 ...
# 4798  El Mariachi just wants to play his guitar and ...
# 4799  A newlywed couple's honeymoon is upended by th...
# 4800  "Signed, Sealed, Delivered" introduces a dedic...
# 4801  When ambitious New York attorney Sam is sent t...
# 4802  Ever since the second grade when he first saw ...
#
#                                                    cast  \
# 0     [{"cast_id": 242, "character": "Jake Sully", "...
# 1     [{"cast_id": 4, "character": "Captain Jack Spa...
# 2     [{"cast_id": 1, "character": "James Bond", "cr...
# 3     [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4     [{"cast_id": 5, "character": "John Carter", "c...
# ...                                                 ...
# 4798  [{"cast_id": 1, "character": "El Mariachi", "c...
# 4799  [{"cast_id": 1, "character": "Buzzy", "credit_...
# 4800  [{"cast_id": 8, "character": "Oliver O\u2019To...
# 4801  [{"cast_id": 3, "character": "Sam", "credit_id...
# 4802  [{"cast_id": 3, "character": "Herself", "credi...
#
#                                                 tagline
# 0                           Enter the World of Pandora.
# 1        At the end of the world, the adventure begins.
# 2                                 A Plan No One Escapes
# 3                                       The Legend Ends
# 4                  Lost in our world, found in another.
# ...                                                 ...
# 4798  He didn't come looking for trouble, but troubl...
# 4799  A newlywed couple's honeymoon is upended by th...
# 4800
# 4801                           A New Yorker in Shanghai
# 4802
#
# [4803 rows x 10 columns]

# %%
movies_df["keywords"] = keywords_df['keywordsv2']
movies_df
# Out:
#           id  popularity                                           homepage  \
# 0      19995  150.437577                        http://www.avatarmovie.com/
# 1        285  139.082615       http://disney.go.com/disneypictures/pirates/
# 2     206647  107.376788        http://www.sonypictures.com/movies/spectre/
# 3      49026  112.312950                 http://www.thedarkknightrises.com/
# 4      49529   43.926995               http://movies.disney.com/john-carter
# ...      ...         ...                                                ...
# 4798    9367   14.269792
# 4799   72766    0.642552
# 4800  231617    1.444476  http://www.hallmarkchannel.com/signedsealeddel...
# 4801  126186    0.857008                        http://shanghaicalling.com/
# 4802   25975    1.929883
#
#                                 original_title     budget     revenue  \
# 0                                       Avatar  237000000  2787965087
# 1     Pirates of the Caribbean: At World's End  300000000   961000000
# 2                                      Spectre  245000000   880674609
# 3                        The Dark Knight Rises  250000000  1084939099
# 4                                  John Carter  260000000   284139100
# ...                                        ...        ...         ...
# 4798                               El Mariachi     220000     2040920
# 4799                                 Newlyweds       9000           0
# 4800                 Signed, Sealed, Delivered          0           0
# 4801                          Shanghai Calling          0           0
# 4802                         My Date with Drew          0           0
#
#                                                  genres  \
# 0     [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...                                                 ...
# 4798  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801                                                 []
# 4802                [{"id": 99, "name": "Documentary"}]
#
#                                                overview  \
# 0     In the 22nd century, a paraplegic Marine is di...
# 1     Captain Barbossa, long believed to be dead, ha...
# 2     A cryptic message from Bond’s past sends him o...
# 3     Following the death of District Attorney Harve...
# 4     John Carter is a war-weary, former military ca...
# ...                                                 ...
# 4798  El Mariachi just wants to play his guitar and ...
# 4799  A newlywed couple's honeymoon is upended by th...
# 4800  "Signed, Sealed, Delivered" introduces a dedic...
# 4801  When ambitious New York attorney Sam is sent t...
# 4802  Ever since the second grade when he first saw ...
#
#                                                    cast  \
# 0     [{"cast_id": 242, "character": "Jake Sully", "...
# 1     [{"cast_id": 4, "character": "Captain Jack Spa...
# 2     [{"cast_id": 1, "character": "James Bond", "cr...
# 3     [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4     [{"cast_id": 5, "character": "John Carter", "c...
# ...                                                 ...
# 4798  [{"cast_id": 1, "character": "El Mariachi", "c...
# 4799  [{"cast_id": 1, "character": "Buzzy", "credit_...
# 4800  [{"cast_id": 8, "character": "Oliver O\u2019To...
# 4801  [{"cast_id": 3, "character": "Sam", "credit_id...
# 4802  [{"cast_id": 3, "character": "Herself", "credi...
#
#                                                 tagline  \
# 0                           Enter the World of Pandora.
# 1        At the end of the world, the adventure begins.
# 2                                 A Plan No One Escapes
# 3                                       The Legend Ends
# 4                  Lost in our world, found in another.
# ...                                                 ...
# 4798  He didn't come looking for trouble, but troubl...
# 4799  A newlywed couple's honeymoon is upended by th...
# 4800
# 4801                           A New Yorker in Shanghai
# 4802
#
#                                                keywords
# 0     ['culture clash', 'future', 'space war', 'spac...
# 1     ['ocean', 'drug abuse', 'exotic island', 'east...
# 2     ['spy', 'based on novel', 'secret agent', 'seq...
# 3     ['dc comics', 'crime fighter', 'terrorist', 's...
# 4     ['based on novel', 'mars', 'medallion', 'space...
# ...                                                 ...
# 4798  ['united states–mexico barrier', 'legs', 'arms...
# 4799                                                 []
# 4800  ['date', 'love at first sight', 'narration', '...
# 4801                                                 []
# 4802  ['obsession', 'camcorder', 'crush', 'dream girl']
#
# [4803 rows x 11 columns]

# %% [markdown]
# # New feature 1 creation: actor names from the cast column of the credits dataset

# %%
movie_cast = movies_df['cast']
names2 = []
for movie in movie_cast:
    submovie = []
    movie = json.loads(movie)
    for attribute in movie: 
        submovie.append(attribute["name"])
    names2.append(submovie)

# %%
del movies_df['cast']
movies_df.insert(6, 'cast', names2, True)

# %%
movies_df['cast'] = movies_df['cast'].astype("string")
movies_df
# Out:
#           id  popularity                                           homepage  \
# 0      19995  150.437577                        http://www.avatarmovie.com/
# 1        285  139.082615       http://disney.go.com/disneypictures/pirates/
# 2     206647  107.376788        http://www.sonypictures.com/movies/spectre/
# 3      49026  112.312950                 http://www.thedarkknightrises.com/
# 4      49529   43.926995               http://movies.disney.com/john-carter
# ...      ...         ...                                                ...
# 4798    9367   14.269792
# 4799   72766    0.642552
# 4800  231617    1.444476  http://www.hallmarkchannel.com/signedsealeddel...
# 4801  126186    0.857008                        http://shanghaicalling.com/
# 4802   25975    1.929883
#
#                                 original_title     budget     revenue  \
# 0                                       Avatar  237000000  2787965087
# 1     Pirates of the Caribbean: At World's End  300000000   961000000
# 2                                      Spectre  245000000   880674609
# 3                        The Dark Knight Rises  250000000  1084939099
# 4                                  John Carter  260000000   284139100
# ...                                        ...        ...         ...
# 4798                               El Mariachi     220000     2040920
# 4799                                 Newlyweds       9000           0
# 4800                 Signed, Sealed, Delivered          0           0
# 4801                          Shanghai Calling          0           0
# 4802                         My Date with Drew          0           0
#
#                                                    cast  \
# 0     ['Sam Worthington', 'Zoe Saldana', 'Sigourney ...
# 1     ['Johnny Depp', 'Orlando Bloom', 'Keira Knight...
# 2     ['Daniel Craig', 'Christoph Waltz', 'Léa Seydo...
# 3     ['Christian Bale', 'Michael Caine', 'Gary Oldm...
# 4     ['Taylor Kitsch', 'Lynn Collins', 'Samantha Mo...
# ...                                                 ...
# 4798  ['Carlos Gallardo', 'Jaime de Hoyos', 'Peter M...
# 4799  ['Edward Burns', 'Kerry Bishé', 'Marsha Dietle...
# 4800  ['Eric Mabius', 'Kristin Booth', 'Crystal Lowe...
# 4801  ['Daniel Henney', 'Eliza Coupe', 'Bill Paxton'...
# 4802  ['Drew Barrymore', 'Brian Herzlinger', 'Corey ...
#
#                                                  genres  \
# 0     [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...                                                 ...
# 4798  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801                                                 []
# 4802                [{"id": 99, "name": "Documentary"}]
#
#                                                overview  \
# 0     In the 22nd century, a paraplegic Marine is di...
# 1     Captain Barbossa, long believed to be dead, ha...
# 2     A cryptic message from Bond’s past sends him o...
# 3     Following the death of District Attorney Harve...
# 4     John Carter is a war-weary, former military ca...
# ...                                                 ...
# 4798  El Mariachi just wants to play his guitar and ...
# 4799  A newlywed couple's honeymoon is upended by th...
# 4800  "Signed, Sealed, Delivered" introduces a dedic...
# 4801  When ambitious New York attorney Sam is sent t...
# 4802  Ever since the second grade when he first saw ...
#
#                                                 tagline  \
# 0                           Enter the World of Pandora.
# 1        At the end of the world, the adventure begins.
# 2                                 A Plan No One Escapes
# 3                                       The Legend Ends
# 4                  Lost in our world, found in another.
# ...                                                 ...
# 4798  He didn't come looking for trouble, but troubl...
# 4799  A newlywed couple's honeymoon is upended by th...
# 4800
# 4801                           A New Yorker in Shanghai
# 4802
#
#                                                keywords
# 0     ['culture clash', 'future', 'space war', 'spac...
# 1     ['ocean', 'drug abuse', 'exotic island', 'east...
# 2     ['spy', 'based on novel', 'secret agent', 'seq...
# 3     ['dc comics', 'crime fighter', 'terrorist', 's...
# 4     ['based on novel', 'mars', 'medallion', 'space...
# ...                                                 ...
# 4798  ['united states–mexico barrier', 'legs', 'arms...
# 4799                                                 []
# 4800  ['date', 'love at first sight', 'narration', '...
# 4801                                                 []
# 4802  ['obsession', 'camcorder', 'crush', 'dream girl']
#
# [4803 rows x 11 columns]

# %% [markdown]
# # New feature 2 creation: taking only the genre out of the genre column from the movies dataset

# %%
movie_genre = movies_df['genres']
names3 = []
for movie in movie_genre:
    submovie = []
    movie = json.loads(movie)
    for attribute in movie: 
        submovie.append(attribute["name"])
    names3.append(submovie)
    for x in names3:
        json.dumps(x)

# %%
del movies_df['genres']
movies_df.insert(4, 'genres', names3, True)

# %%
movies_df['genres'] = movies_df['genres'].astype("string")
movies_df
# Out:
#           id  popularity                                           homepage  \
# 0      19995  150.437577                        http://www.avatarmovie.com/
# 1        285  139.082615       http://disney.go.com/disneypictures/pirates/
# 2     206647  107.376788        http://www.sonypictures.com/movies/spectre/
# 3      49026  112.312950                 http://www.thedarkknightrises.com/
# 4      49529   43.926995               http://movies.disney.com/john-carter
# ...      ...         ...                                                ...
# 4798    9367   14.269792
# 4799   72766    0.642552
# 4800  231617    1.444476  http://www.hallmarkchannel.com/signedsealeddel...
# 4801  126186    0.857008                        http://shanghaicalling.com/
# 4802   25975    1.929883
#
#                                 original_title  \
# 0                                       Avatar
# 1     Pirates of the Caribbean: At World's End
# 2                                      Spectre
# 3                        The Dark Knight Rises
# 4                                  John Carter
# ...                                        ...
# 4798                               El Mariachi
# 4799                                 Newlyweds
# 4800                 Signed, Sealed, Delivered
# 4801                          Shanghai Calling
# 4802                         My Date with Drew
#
#                                                  genres     budget  \
# 0     ['Action', 'Adventure', 'Fantasy', 'Science Fi...  237000000
# 1                    ['Adventure', 'Fantasy', 'Action']  300000000
# 2                      ['Action', 'Adventure', 'Crime']  245000000
# 3              ['Action', 'Crime', 'Drama', 'Thriller']  250000000
# 4            ['Action', 'Adventure', 'Science Fiction']  260000000
# ...                                                 ...        ...
# 4798                    ['Action', 'Crime', 'Thriller']     220000
# 4799                              ['Comedy', 'Romance']       9000
# 4800         ['Comedy', 'Drama', 'Romance', 'TV Movie']          0
# 4801                                                 []          0
# 4802                                    ['Documentary']          0
#
#          revenue                                               cast  \
# 0     2787965087  ['Sam Worthington', 'Zoe Saldana', 'Sigourney ...
# 1      961000000  ['Johnny Depp', 'Orlando Bloom', 'Keira Knight...
# 2      880674609  ['Daniel Craig', 'Christoph Waltz', 'Léa Seydo...
# 3     1084939099  ['Christian Bale', 'Michael Caine', 'Gary Oldm...
# 4      284139100  ['Taylor Kitsch', 'Lynn Collins', 'Samantha Mo...
# ...          ...                                                ...
# 4798     2040920  ['Carlos Gallardo', 'Jaime de Hoyos', 'Peter M...
# 4799           0  ['Edward Burns', 'Kerry Bishé', 'Marsha Dietle...
# 4800           0  ['Eric Mabius', 'Kristin Booth', 'Crystal Lowe...
# 4801           0  ['Daniel Henney', 'Eliza Coupe', 'Bill Paxton'...
# 4802           0  ['Drew Barrymore', 'Brian Herzlinger', 'Corey ...
#
#                                                overview  \
# 0     In the 22nd century, a paraplegic Marine is di...
# 1     Captain Barbossa, long believed to be dead, ha...
# 2     A cryptic message from Bond’s past sends him o...
# 3     Following the death of District Attorney Harve...
# 4     John Carter is a war-weary, former military ca...
# ...                                                 ...
# 4798  El Mariachi just wants to play his guitar and ...
# 4799  A newlywed couple's honeymoon is upended by th...
# 4800  "Signed, Sealed, Delivered" introduces a dedic...
# 4801  When ambitious New York attorney Sam is sent t...
# 4802  Ever since the second grade when he first saw ...
#
#                                                 tagline  \
# 0                           Enter the World of Pandora.
# 1        At the end of the world, the adventure begins.
# 2                                 A Plan No One Escapes
# 3                                       The Legend Ends
# 4                  Lost in our world, found in another.
# ...                                                 ...
# 4798  He didn't come looking for trouble, but troubl...
# 4799  A newlywed couple's honeymoon is upended by th...
# 4800
# 4801                           A New Yorker in Shanghai
# 4802
#
#                                                keywords
# 0     ['culture clash', 'future', 'space war', 'spac...
# 1     ['ocean', 'drug abuse', 'exotic island', 'east...
# 2     ['spy', 'based on novel', 'secret agent', 'seq...
# 3     ['dc comics', 'crime fighter', 'terrorist', 's...
# 4     ['based on novel', 'mars', 'medallion', 'space...
# ...                                                 ...
# 4798  ['united states–mexico barrier', 'legs', 'arms...
# 4799                                                 []
# 4800  ['date', 'love at first sight', 'narration', '...
# 4801                                                 []
# 4802  ['obsession', 'camcorder', 'crush', 'dream girl']
#
# [4803 rows x 11 columns]

# %% [markdown]
# # Vectorize Data

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
tfidf = TfidfVectorizer(analyzer='word', stop_words='english', token_pattern=r"(?u)\b\w\w+\b|!|\?|\"|\'|\.")

# %%
movies_matrix = tfidf.fit_transform(movies_df['overview'].values.astype('U') + movies_df['keywords'] +movies_df['genres']+movies_df['cast'])
movies_matrix
# Out:
# <4803x53334 sparse matrix of type '<class 'numpy.float64'>'
# 	with 396211 stored elements in Compressed Sparse Row format>

# %% [markdown]
# # Application of cosine similarity

# %%
from sklearn.metrics.pairwise import cosine_similarity
#Using cosine similarties to analyze the similarity of the texts using numbers
cosine_similarities = cosine_similarity(movies_matrix)
cosine_similarities.shape
# Out:
# (4803, 4803)

# %%
cosine_similarities
# Out:
# array([[1.        , 0.79212448, 0.80393344, ..., 0.48589457, 0.20266506,
#         0.44266582],
#        [0.79212448, 1.        , 0.75850725, ..., 0.46295994, 0.1854463 ,
#         0.41937879],
#        [0.80393344, 0.75850725, 1.        , ..., 0.46503292, 0.18713557,
#         0.42122227],
#        ...,
#        [0.48589457, 0.46295994, 0.46503292, ..., 1.        , 0.12923419,
#         0.28063248],
#        [0.20266506, 0.1854463 , 0.18713557, ..., 0.12923419, 1.        ,
#         0.1171044 ],
#        [0.44266582, 0.41937879, 0.42122227, ..., 0.28063248, 0.1171044 ,
#         1.        ]])

# %%
#Sorting out the cosine array
cosine_similarities[15].argsort()[:-10:-1]
# Out:
# array([  15,   63,  109,  637,  598, 2217,  218, 4216,    3], dtype=int64)

# %%
#using a for loop to show the similarities for each movies, based their id.
similarities = {}
for i in range(len(cosine_similarities)):
   
    similar_indices = cosine_similarities[i].argsort()[:-50:-1]
    

    similarities[movies_df['original_title'].iloc[i]] = [(cosine_similarities[i][x], movies_df['id'][x], movies_df['original_title'][x])
                                           for x in similar_indices][1:]

similarities
# Out:
# {'Avatar': [(0.8796863276267765, 80585, 'Rock of Ages'),
#   (0.8791161773486965, 82695, 'Les Misérables'),
#   (0.8742289672338663, 324668, 'Jason Bourne'),
#   (0.8737398754428343, 9716, 'Everyone Says I Love You'),
#   (0.8732390417131553, 13475, 'Star Trek'),
#   (0.872272581258444, 155, 'The Dark Knight'),
#   (0.8706611234431079, 49026, 'The Dark Knight Rises'),
#   (0.870433981063508, 18, 'The Fifth Element'),
#   (0.8687064012079789, 39254, 'Real Steel'),
#   (0.8685997339460025, 3083, 'Mr. Smith Goes to Washington'),
#   (0.866556285419424, 2976, 'Hairspray'),
#   (0.8652942012131238, 10661, "You Don't Mess with the Zohan"),
#   (0.8642019809268559, 106646, 'The Wolf of Wall Street'),
#   (0.8634353646587241, 68728, 'Oz: The Great and Powerful'),
#   (0.8634294901988516, 68718, 'Django Unchained'),
#   (0.8632798844670142, 11, 'Star Wars'),
#   (0.8627136743821271, 272, 'Batman Begins'),
#   (0.8613509447741342, 559, 'Spider-Man 3'),
#   (0.8613298708867884, 209112, 'Batman v Superman: Dawn of Justice'),
#   (0.860858324800305, 291805, 'Now You See Me 2'),
#   (0.8601124953361066, 11615, 'The Life of David Gale'),
#   (0.8597072607601582, 770, 'Gone with the Wind'),
#   (0.8581053847247008, 769, 'GoodFellas'),
#   (0.8572980352169459, 818, 'Austin Powers in Goldmember'),
#   (0.8570002653171341, 4723, 'Southland Tales'),
#   (0.855192000111499, 686, 'Contact'),
#   (0.8536481696166962, 34106, "You Can't Take It With You"),
#   (0.8531775273988027, 114150, 'Pitch Perfect'),
#   (0.8529574818504154, 68721, 'Iron Man 3'),
#   (0.8529036711261211, 1892, 'Return of the Jedi'),
#   (0.852685514926141, 297761, 'Suicide Squad'),
#   (0.8519593163052511, 4982, 'American Gangster'),
#   (0.8517341952281771, 676, 'Pearl Harbor'),
#   (0.8517180399831871, 1891, 'The Empire Strikes Back'),
#   (0.8506321920417462, 318846, 'The Big Short'),
#   (0.8503785794805238, 1924, 'Superman'),
#   (0.8501463288313086, 54138, 'Star Trek Into Darkness'),
#   (0.8492872847093909, 597, 'Titanic'),
#   (0.84833325322121, 248774, 'Obvious Child'),
#   (0.8482189415067993, 640, 'Catch Me If You Can'),
#   (0.8475945551784777, 171274, 'Inherent Vice'),
#   (0.8474907257200713, 2604, 'Born on the Fourth of July'),
#   (0.8456240577688431, 116741, 'The Internship'),
#   (0.8454976857047749, 268920, 'Hot Pursuit'),
#   (0.8445711047535093, 24428, 'The Avengers'),
#   (0.8441064057775275, 44564, 'The Dilemma'),
#   (0.8440911404047375, 2749, '15 Minutes'),
#   (0.8439577819526258, 10673, 'Wall Street')],
#  "Pirates of the Caribbean: At World's End": [(0.8772413231357464,
#    58,
#    "Pirates of the Caribbean: Dead Man's Chest"),
#   (0.8365482104825834,
#    22,
#    'Pirates of the Caribbean: The Curse of the Black Pearl'),
#   (0.8283094503855557, 82695, 'Les Misérables'),
#   (0.8270744018679709, 80585, 'Rock of Ages'),
#   (0.822956008395266, 9716, 'Everyone Says I Love You'),
#   (0.8218449977747297, 324668, 'Jason Bourne'),
#   (0.8200222148431517, 155, 'The Dark Knight'),
#   (0.8198526016611277, 13475, 'Star Trek'),
#   (0.8176593097550757, 49026, 'The Dark Knight Rises'),
#   (0.8166837497736987, 3083, 'Mr. Smith Goes to Washington'),
#   (0.8164807878113565, 39254, 'Real Steel'),
#   (0.8163252395928464, 18, 'The Fifth Element'),
#   (0.8161745859813269, 68728, 'Oz: The Great and Powerful'),
#   (0.8152553879219454, 2976, 'Hairspray'),
#   (0.8144851782670347, 10661, "You Don't Mess with the Zohan"),
#   (0.8138323859390998, 272, 'Batman Begins'),
#   (0.8138022547200526, 559, 'Spider-Man 3'),
#   (0.8135755799863736, 68718, 'Django Unchained'),
#   (0.8119046532041008, 11, 'Star Wars'),
#   (0.8118382509758134, 106646, 'The Wolf of Wall Street'),
#   (0.8115775596337677, 291805, 'Now You See Me 2'),
#   (0.8110507738833492, 11615, 'The Life of David Gale'),
#   (0.8097528751027442, 770, 'Gone with the Wind'),
#   (0.8096219286080145, 209112, 'Batman v Superman: Dawn of Justice'),
#   (0.8076560188910231, 818, 'Austin Powers in Goldmember'),
#   (0.8059615511617215, 1924, 'Superman'),
#   (0.8058794644411064, 769, 'GoodFellas'),
#   (0.8058561820830118, 34106, "You Can't Take It With You"),
#   (0.8050007915273147, 4723, 'Southland Tales'),
#   (0.8042195104944339, 597, 'Titanic'),
#   (0.8039575906569745, 4982, 'American Gangster'),
#   (0.8020979894049467, 114150, 'Pitch Perfect'),
#   (0.801812118224832, 171274, 'Inherent Vice'),
#   (0.8016849894295304, 297761, 'Suicide Squad'),
#   (0.7998161616848165, 68721, 'Iron Man 3'),
#   (0.7996627651252117, 640, 'Catch Me If You Can'),
#   (0.799655380143466, 676, 'Pearl Harbor'),
#   (0.7996392175865984, 1892, 'Return of the Jedi'),
#   (0.7994391235308365, 686, 'Contact'),
#   (0.7982639898406275, 10138, 'Iron Man 2'),
#   (0.7982054610915668, 248774, 'Obvious Child'),
#   (0.7977616544967746, 1891, 'The Empire Strikes Back'),
#   (0.796998483000467, 318846, 'The Big Short'),
#   (0.7961765633975159, 24428, 'The Avengers'),
#   (0.7960294144968582, 5503, 'The Fugitive'),
#   (0.7958946859194229, 105, 'Back to the Future'),
#   (0.7956744902948631, 268920, 'Hot Pursuit'),
#   (0.7949626545909437, 2749, '15 Minutes')],
#  'Spectre': [(0.840406594526015, 82695, 'Les Misérables'),
#   (0.8390873199674553, 80585, 'Rock of Ages'),
#   (0.8336938224179095, 324668, 'Jason Bourne'),
#   (0.833436471833062, 9716, 'Everyone Says I Love You'),
#   (0.8327273015827886, 155, 'The Dark Knight'),
#   (0.830379112793692, 49026, 'The Dark Knight Rises'),
#   (0.8291927286929123, 3083, 'Mr. Smith Goes to Washington'),
#   (0.8288221185329198, 2976, 'Hairspray'),
#   (0.8283625570996287, 13475, 'Star Trek'),
#   (0.8269576199605146, 39254, 'Real Steel'),
#   (0.8263138219639979, 18, 'The Fifth Element'),
#   (0.8258506640677263, 272, 'Batman Begins'),
#   (0.8257451516288062, 10661, "You Don't Mess with the Zohan"),
#   (0.8255987601318706, 68718, 'Django Unchained'),
#   (0.8253522303870104, 106646, 'The Wolf of Wall Street'),
#   (0.8234843012318975, 291805, 'Now You See Me 2'),
#   (0.8225419766445217, 68728, 'Oz: The Great and Powerful'),
#   (0.822256474077357, 559, 'Spider-Man 3'),
#   (0.8210581731522488, 818, 'Austin Powers in Goldmember'),
#   (0.8200691727792511, 770, 'Gone with the Wind'),
#   (0.8199938192697558, 209112, 'Batman v Superman: Dawn of Justice'),
#   (0.8199401614625534, 11, 'Star Wars'),
#   (0.8193258878869334, 11615, 'The Life of David Gale'),
#   (0.8187511120994821, 769, 'GoodFellas'),
#   (0.8175302272396376, 4723, 'Southland Tales'),
#   (0.8153147697518425, 34106, "You Can't Take It With You"),
#   (0.8130330766652466, 4982, 'American Gangster'),
#   (0.812751530242008, 114150, 'Pitch Perfect'),
#   (0.8125086068326252, 297761, 'Suicide Squad'),
#   (0.8114145166738994, 676, 'Pearl Harbor'),
#   (0.8111606185277482, 68721, 'Iron Man 3'),
#   (0.8102432251002466, 686, 'Contact'),
#   (0.8100146961312275, 1892, 'Return of the Jedi'),
#   (0.8099754377910754, 1924, 'Superman'),
#   (0.8098784370979011, 318846, 'The Big Short'),
#   (0.8092111102558559, 640, 'Catch Me If You Can'),
#   (0.8089889616774906, 248774, 'Obvious Child'),
#   (0.8088086610761877, 2749, '15 Minutes'),
#   (0.8082660018650956, 1891, 'The Empire Strikes Back'),
#   (0.8072656438948388, 597, 'Titanic'),
#   (0.8066960961001366, 171274, 'Inherent Vice'),
#   (0.8052241056327605, 2604, 'Born on the Fourth of July'),
#   (0.8051382911034468, 270487, 'Hail, Caesar!'),
#   (0.804854923904482, 675, 'Harry Potter and the Order of the Phoenix'),
#   (0.8047415666627558, 268920, 'Hot Pursuit'),
#   (0.8044552297468455, 11397, 'Not Another Teen Movie'),
#   (0.8042709282868332, 44564, 'The Dilemma'),
#   (0.8040421520609963, 116741, 'The Internship')],
#  'The Dark Knight Rises': [(0.9085936942668328, 155, 'The Dark Knight'),
#   (0.9064335984726725, 82695, 'Les Misérables'),
#   (0.9043015512082087, 80585, 'Rock of Ages'),
#   (0.9038173801506688, 272, 'Batman Begins'),
#   (0.9020494392325409, 324668, 'Jason Bourne'),
#   (0.9011360153895304, 9716, 'Everyone Says I Love You'),
#   (0.8978912211436615, 3083, 'Mr. Smith Goes to Washington'),
#   (0.8975403656335652, 106646, 'The Wolf of Wall Street'),
#   (0.8974153308797798, 13475, 'Star Trek'),
#   (0.8961132709527599, 2976, 'Hairspray'),
#   (0.8954547819085674, 39254, 'Real Steel'),
#   (0.8940314210854335, 18, 'The Fifth Element'),
#   (0.8927030707317686, 10661, "You Don't Mess with the Zohan"),
#   (0.8919740786473059, 68718, 'Django Unchained'),
#   (0.8915518998515594, 209112, 'Batman v Superman: Dawn of Justice'),
#   (0.8907583646582949, 68728, 'Oz: The Great and Powerful'),
#   (0.8904147059854267, 559, 'Spider-Man 3'),
#   (0.8877133855160759, 291805, 'Now You See Me 2'),
#   (0.8876653518377118, 11615, 'The Life of David Gale'),
#   (0.8872086422682282, 11, 'Star Wars'),
#   (0.8856393257007696, 769, 'GoodFellas'),
#   (0.8852541023062124, 770, 'Gone with the Wind'),
#   (0.8836944320312451, 818, 'Austin Powers in Goldmember'),
#   (0.8815788874672323, 4723, 'Southland Tales'),
#   (0.8808015988493391, 34106, "You Can't Take It With You"),
#   (0.8806420741752717, 1924, 'Superman'),
#   (0.8801197910679788, 297761, 'Suicide Squad'),
#   (0.8796102293008843, 4982, 'American Gangster'),
#   (0.8787968275193722, 686, 'Contact'),
#   (0.8781310325118754, 68721, 'Iron Man 3'),
#   (0.8780694040448555, 676, 'Pearl Harbor'),
#   (0.8763274409061308, 640, 'Catch Me If You Can'),
#   (0.8762912654260374, 1892, 'Return of the Jedi'),
#   (0.8760186613370871, 24428, 'The Avengers'),
#   (0.8759504138340083, 114150, 'Pitch Perfect'),
#   (0.8753892191910204, 248774, 'Obvious Child'),
#   (0.8753328534218118, 318846, 'The Big Short'),
#   (0.8747017432698209, 270487, 'Hail, Caesar!'),
#   (0.8735438509425962, 268920, 'Hot Pursuit'),
#   (0.87297147114406, 1891, 'The Empire Strikes Back'),
#   (0.8729256956636839, 597, 'Titanic'),
#   (0.8728143587635483, 2604, 'Born on the Fourth of July'),
#   (0.8727587629634805, 11397, 'Not Another Teen Movie'),
#   (0.8715977867553389, 214756, 'Ted 2'),
#   (0.8715943819717801, 116741, 'The Internship'),
#   (0.870920666363008, 171274, 'Inherent Vice'),
#   (0.8708813540531214, 2749, '15 Minutes'),
#   (0.870799934870045, 3580, 'Changeling')],
#  'John Carter': [(0.7879350717209015, 82695, 'Les Misérables'),
#   (0.7805421647937993, 80585, 'Rock of Ages'),
#   (0.7782046051306518, 13475, 'Star Trek'),
#   (0.7773105991053662, 9716, 'Everyone Says I Love You'),
#   (0.7765162960531536, 324668, 'Jason Bourne'),
#   (0.7759459034977099, 18, 'The Fifth Element'),
#   (0.7757113388110835, 49026, 'The Dark Knight Rises'),
#   (0.7752407347717873, 2976, 'Hairspray'),
#   (0.775012824166597, 3083, 'Mr. Smith Goes to Washington'),
#   (0.7733956132588651, 155, 'The Dark Knight'),
#   (0.7733077838512695, 68718, 'Django Unchained'),
#   (0.773190606949307, 39254, 'Real Steel'),
#   (0.7717352514086173, 272, 'Batman Begins'),
#   (0.7711847743906366, 559, 'Spider-Man 3'),
#   (0.7702573558626085, 10661, "You Don't Mess with the Zohan"),
#   (0.7687118865375685, 11, 'Star Wars'),
#   (0.7684124357577854, 68728, 'Oz: The Great and Powerful'),
#   (0.7680803752138341, 106646, 'The Wolf of Wall Street'),
#   (0.7670188950932046, 19995, 'Avatar'),
#   (0.7646538158780801, 4723, 'Southland Tales'),
#   (0.7646353921438235, 291805, 'Now You See Me 2'),
#   (0.7641424382227002, 11615, 'The Life of David Gale'),
#   (0.763814805169439, 770, 'Gone with the Wind'),
#   (0.7635706623199222, 209112, 'Batman v Superman: Dawn of Justice'),
#   (0.7630032336996365, 818, 'Austin Powers in Goldmember'),
#   (0.7627538728013421, 769, 'GoodFellas'),
#   (0.7622808093531125, 68721, 'Iron Man 3'),
#   (0.7622589558186098, 34106, "You Can't Take It With You"),
#   (0.7611128089063953, 686, 'Contact'),
#   (0.7604339301356879, 1924, 'Superman'),
#   (0.7584432093449255, 1892, 'Return of the Jedi'),
#   (0.7583158508127567, 297761, 'Suicide Squad'),
#   (0.7582287307132322, 676, 'Pearl Harbor'),
#   (0.7581415297585493, 4982, 'American Gangster'),
#   (0.7568228936970731, 248774, 'Obvious Child'),
#   (0.7566012722317444, 114150, 'Pitch Perfect'),
#   (0.756052003839667, 1891, 'The Empire Strikes Back'),
#   (0.7559892592879353, 268920, 'Hot Pursuit'),
#   (0.7555066552883595, 640, 'Catch Me If You Can'),
#   (0.7553194264749802, 597, 'Titanic'),
#   (0.7546870947076006, 10138, 'Iron Man 2'),
#   (0.7545438339366624, 54138, 'Star Trek Into Darkness'),
#   (0.7540666863860183, 2604, 'Born on the Fourth of July'),
#   (0.7538155082899828, 318846, 'The Big Short'),
#   (0.7534968557688023, 171274, 'Inherent Vice'),
#   (0.7533332180949477, 24428, 'The Avengers'),
#   (0.7523480424419308, 2749, '15 Minutes'),
#   (0.752130018122414, 271110, 'Captain America: Civil War')],
#  'Spider-Man 3': [(0.8992873186695344, 80585, 'Rock of Ages'),
#   (0.8988019692744458, 82695, 'Les Misérables'),
#   (0.8945811110052362, 9716, 'Everyone Says I Love You'),
#   (0.8935609403676765, 324668, 'Jason Bourne'),
#   (0.8904147059854267, 49026, 'The Dark Knight Rises'),
#   (0.889662568959616, 155, 'The Dark Knight'),
#   (0.8890075631057295, 68728, 'Oz: The Great and Powerful'),
#   (0.8889304306520489, 2976, 'Hairspray'),
#   (0.8888069468635841, 3083, 'Mr. Smith Goes to Washington'),
#   (0.8876270497424701, 39254, 'Real Steel'),
#   (0.8873720213609149, 13475, 'Star Trek'),
#   (0.8848079689283941, 10661, "You Don't Mess with the Zohan"),
#   (0.8839287851778816, 68718, 'Django Unchained'),
#   (0.883895701845748, 18, 'The Fifth Element'),
#   (0.8828240405342704, 106646, 'The Wolf of Wall Street'),
#   (0.8824718971732866, 558, 'Spider-Man 2'),
#   (0.8809660334601308, 11, 'Star Wars'),
#   (0.8809141068722485, 272, 'Batman Begins'),
#   (0.8806054604387694, 209112, 'Batman v Superman: Dawn of Justice'),
#   (0.8805577103312677, 11615, 'The Life of David Gale'),
#   (0.8800215952256932, 770, 'Gone with the Wind'),
#   (0.8793853551928544, 291805, 'Now You See Me 2'),
#   (0.8786921134979255, 769, 'GoodFellas'),
#   (0.8777070074071802, 34106, "You Can't Take It With You"),
#   (0.8774362054904297, 818, 'Austin Powers in Goldmember'),
#   (0.8745271061026912, 4982, 'American Gangster'),
#   (0.8740354137425936, 4723, 'Southland Tales'),
#   (0.8736478160616209, 557, 'Spider-Man'),
#   (0.8718785327844296, 1924, 'Superman'),
#   (0.8718075876451247, 68721, 'Iron Man 3'),
#   (0.8711252358396947, 1892, 'Return of the Jedi'),
#   (0.8699753766369841, 297761, 'Suicide Squad'),
#   (0.8699270534693764, 686, 'Contact'),
#   (0.8699014711048947, 10138, 'Iron Man 2'),
#   (0.8696264906805348, 114150, 'Pitch Perfect'),
#   (0.8684613460616866, 640, 'Catch Me If You Can'),
#   (0.8679125731446898, 676, 'Pearl Harbor'),
#   (0.8675293315587771, 24428, 'The Avengers'),
#   (0.8670836559937688, 171274, 'Inherent Vice'),
#   (0.8666909981628442, 248774, 'Obvious Child'),
#   (0.8662506616267874, 116741, 'The Internship'),
#   (0.8657954486351815, 597, 'Titanic'),
#   (0.8655752749869001, 268920, 'Hot Pursuit'),
#   (0.8644298450400157, 214756, 'Ted 2'),
#   (0.8642928020939595, 44564, 'The Dilemma'),
#   (0.8642899972555559, 1891, 'The Empire Strikes Back'),
#   (0.8641405199341119, 2604, 'Born on the Fourth of July'),
#   (0.863376974704262, 318846, 'The Big Short')],
#  'Tangled': [(0.6636840907550825, 82695, 'Les Misérables'),
#   (0.6630875729426718, 9716, 'Everyone Says I Love You'),
#   (0.6627993938694551, 80585, 'Rock of Ages'),
#   (0.6594206849055582, 13475, 'Star Trek'),
#   (0.6592738140755753, 39254, 'Real Steel'),
#   (0.6573429417915359, 324668, 'Jason Bourne'),
#   (0.6572373240404432, 155, 'The Dark Knight'),
#   (0.6567104490676487, 2976, 'Hairspray'),
#   (0.6555758754258433, 49026, 'The Dark Knight Rises'),
#   (0.6554359643673733, 3083, 'Mr. Smith Goes to Washington'),
#   (0.6540436916582745, 68728, 'Oz: The Great and Powerful'),
#   (0.653303107856365, 272, 'Batman Begins'),
#   (0.6527262235153375, 68718, 'Django Unchained'),
#   (0.652390940790002, 18, 'The Fifth Element'),
#   (0.6521487595217665, 10661, "You Don't Mess with the Zohan"),
#   (0.651127036032509, 818, 'Austin Powers in Goldmember'),
#   (0.651036666288586, 106646, 'The Wolf of Wall Street'),
#   (0.6501539222647693, 291805, 'Now You See Me 2'),
#   (0.6500405409548101, 559, 'Spider-Man 3'),
#   (0.6495971563115516, 209112, 'Batman v Superman: Dawn of Justice'),
#   (0.6489347594582705, 11615, 'The Life of David Gale'),
#   (0.648584047331722, 105, 'Back to the Future'),
#   (0.6484362008419544, 11, 'Star Wars'),
#   (0.6479750123814891, 770, 'Gone with the Wind'),
#   (0.6467375842298451, 4723, 'Southland Tales'),
#   (0.6463757806545812, 769, 'GoodFellas'),
#   (0.6444170014202617, 4982, 'American Gangster'),
#   (0.6443642024623644, 34106, "You Can't Take It With You"),
#   (0.6424218866882807, 318846, 'The Big Short'),
#   (0.6423851664635483, 11397, 'Not Another Teen Movie'),
#   (0.6422430632792566, 686, 'Contact'),
#   (0.6418310547164352, 114150, 'Pitch Perfect'),
#   (0.6412385841503547, 1924, 'Superman'),
#   (0.6411888853300857, 597, 'Titanic'),
#   (0.6408502953308999, 68721, 'Iron Man 3'),
#   (0.6407678090336967, 1892, 'Return of the Jedi'),
#   (0.6404734164700849, 676, 'Pearl Harbor'),
#   (0.6403185617515234, 268920, 'Hot Pursuit'),
#   (0.6402420376225636, 5503, 'The Fugitive'),
#   (0.6401945919469729, 14560, 'Paul Blart: Mall Cop'),
#   (0.6398470936237833, 297761, 'Suicide Squad'),
#   (0.639696720499969, 2604, 'Born on the Fourth of July'),
#   (0.6387623228861565, 248774, 'Obvious Child'),
#   (0.6387234429130431, 3580, 'Changeling'),
#   (0.6383963256240146, 2749, '15 Minutes'),
#   (0.6380082419995089, 10673, 'Wall Street'),
#   (0.6376917309334023, 640, 'Catch Me If You Can'),
#   (0.6375796753124868, 19995, 'Avatar')],
#  'Avengers: Age of Ultron': [(0.8424374508905926, 82695, 'Les Misérables'),
#   (0.8366783688048262, 80585, 'Rock of Ages'),
#   (0.8331577196319525, 324668, 'Jason Bourne'),
#   (0.8328644320109255, 9716, 'Everyone Says I Love You'),
#   (0.831871179660075, 24428, 'The Avengers'),
#   (0.8315254826225947, 13475, 'Star Trek'),
#   (0.8303293363621524, 49026, 'The Dark Knight Rises'),
#   (0.829929923298186, 155, 'The Dark Knight'),
#   (0.8292418824456094, 3083, 'Mr. Smith Goes to Washington'),
#   (0.8290605947524653, 68721, 'Iron Man 3'),
#   (0.8287388573745992, 271110, 'Captain America: Civil War'),
#   (0.8284131009429974, 39254, 'Real Steel'),
#   (0.8277950792570009, 2976, 'Hairspray'),
#   (0.8263731778165302, 68718, 'Django Unchained'),
#   (0.8261725664320935, 18, 'The Fifth Element'),
#   (0.8253162974111987, 106646, 'The Wolf of Wall Street'),
#   (0.8251348895771127, 559, 'Spider-Man 3'),
#   (0.824304935090159, 10661, "You Don't Mess with the Zohan"),
#   (0.8239310915372616, 291805, 'Now You See Me 2'),
#   (0.8237101440810101, 10138, 'Iron Man 2'),
#   (0.8234809605359257, 68728, 'Oz: The Great and Powerful'),
#   (0.8233340559775526, 272, 'Batman Begins'),
#   (0.821908196028469, 11, 'Star Wars'),
#   (0.8205741961702481, 818, 'Austin Powers in Goldmember'),
#   (0.8201983720062711, 11615, 'The Life of David Gale'),
#   (0.8199112677445383, 209112, 'Batman v Superman: Dawn of Justice'),
#   (0.8196433922397096, 769, 'GoodFellas'),
#   (0.8171641426890032, 118340, 'Guardians of the Galaxy'),
#   (0.8164075340007146, 770, 'Gone with the Wind'),
#   (0.81615074686557, 34106, "You Can't Take It With You"),
#   (0.8155095369798807, 4982, 'American Gangster'),
#   (0.8153608758238877, 4723, 'Southland Tales'),
#   (0.8153134318172972, 1924, 'Superman'),
#   (0.8124993192393271, 1892, 'Return of the Jedi'),
#   (0.8122577925564857, 676, 'Pearl Harbor'),
#   (0.811471078610631, 1726, 'Iron Man'),
#   (0.8113197258726925, 297761, 'Suicide Squad'),
#   (0.8111548013773201, 686, 'Contact'),
#   (0.8102673910523153, 114150, 'Pitch Perfect'),
#   (0.8099976256758806, 597, 'Titanic'),
#   (0.8094921970431403, 318846, 'The Big Short'),
#   (0.8080689728679905, 640, 'Catch Me If You Can'),
#   (0.8073767431037635, 1891, 'The Empire Strikes Back'),
#   (0.807324565163357, 11397, 'Not Another Teen Movie'),
#   (0.8065472247762966, 248774, 'Obvious Child'),
#   (0.8065392603573045, 19995, 'Avatar'),
#   (0.8061791899310464, 2604, 'Born on the Fourth of July'),
#   (0.8059141228007167, 268920, 'Hot Pursuit')],
#  'Harry Potter and the Half-Blood Prince': [(0.8890219560819311,
#    675,
#    'Harry Potter and the Order of the Phoenix'),
#   (0.8694891046049571, 674, 'Harry Potter and the Goblet of Fire'),
#   (0.8641502639003985, 672, 'Harry Potter and the Chamber of Secrets'),
#   (0.8621441947868415, 673, 'Harry Potter and the Prisoner of Azkaban'),
#   (0.8466316205729553, 82695, 'Les Misérables'),
#   (0.8458176035262642, 671, "Harry Potter and the Philosopher's Stone"),
#   (0.8407763952899804, 80585, 'Rock of Ages'),
#   (0.8388645388298295, 3083, 'Mr. Smith Goes to Washington'),
#   (0.8377254680731197, 9716, 'Everyone Says I Love You'),
#   (0.8357696782991204, 324668, 'Jason Bourne'),
#   (0.8351999573252893, 155, 'The Dark Knight'),
#   (0.8328185028680835, 49026, 'The Dark Knight Rises'),
#   (0.8317083806567843, 272, 'Batman Begins'),
#   (0.8310010392651074, 68728, 'Oz: The Great and Powerful'),
#   (0.8304992879857389, 13475, 'Star Trek'),
#   (0.8304288523129725, 39254, 'Real Steel'),
#   (0.8296748371939174, 2976, 'Hairspray'),
#   (0.829489768700293, 18, 'The Fifth Element'),
#   (0.8293799728836959, 10661, "You Don't Mess with the Zohan"),
#   (0.8279196047499081, 291805, 'Now You See Me 2'),
#   (0.8273458489143977, 68718, 'Django Unchained'),
#   (0.827087918228243, 106646, 'The Wolf of Wall Street'),
#   (0.8263296938625545, 11, 'Star Wars'),
#   (0.826188266016267, 770, 'Gone with the Wind'),
#   (0.8246937724639244, 769, 'GoodFellas'),
#   (0.8238168491712589, 11615, 'The Life of David Gale'),
#   (0.8237229777205998, 559, 'Spider-Man 3'),
#   (0.8220042563957206, 34106, "You Can't Take It With You"),
#   (0.8218055758519089, 209112, 'Batman v Superman: Dawn of Justice'),
#   (0.820996204830312, 818, 'Austin Powers in Goldmember'),
#   (0.8179442968753458, 1924, 'Superman'),
#   (0.8171285983159976, 4723, 'Southland Tales'),
#   (0.8166532479988617, 297761, 'Suicide Squad'),
#   (0.8164856620710256, 114150, 'Pitch Perfect'),
#   (0.8154500126980317, 686, 'Contact'),
#   (0.8153896267872046, 1892, 'Return of the Jedi'),
#   (0.8150943292108153, 4982, 'American Gangster'),
#   (0.8138183124666065, 676, 'Pearl Harbor'),
#   (0.8137577204689093, 68721, 'Iron Man 3'),
#   (0.8126550944520796, 270487, 'Hail, Caesar!'),
#   (0.812590051796257, 318846, 'The Big Short'),
#   (0.8124386559379831, 248774, 'Obvious Child'),
#   (0.8123544194113, 1891, 'The Empire Strikes Back'),
#   (0.8123210652803039, 11397, 'Not Another Teen Movie'),
#   (0.8118276868418127, 640, 'Catch Me If You Can'),
#   (0.8117446304894076, 24428, 'The Avengers'),
#   (0.8108267358434645, 597, 'Titanic'),
#   (0.8101957502069026, 118340, 'Guardians of the Galaxy')],
#  'Batman v Superman: Dawn of Justice': [(0.8966036773446273,
#    80585,
#    'Rock of Ages'),
#   (0.8941230871182198, 82695, 'Les Misérables'),
#   (0.8915913484208157, 155, 'The Dark Knight'),
#   (0.8915518998515594, 49026, 'The Dark Knight Rises'),
#   (0.890550568875364, 9716, 'Everyone Says I Love You'),
#   (0.8890864735673305, 39254, 'Real Steel'),
#   (0.8887410544655663, 324668, 'Jason Bourne'),
#   (0.8876230829885841, 3083, 'Mr. Smith Goes to Washington'),
#   (0.8860900087977709, 2976, 'Hairspray'),
#   (0.8856441572390541, 13475, 'Star Trek'),
#   (0.8854797482796071, 272, 'Batman Begins'),
#   (0.8838131630067013, 68718, 'Django Unchained'),
#   (0.8824839077615815, 106646, 'The Wolf of Wall Street'),
#   (0.8821526638803241, 68728, 'Oz: The Great and Powerful'),
#   (0.8816845956161755, 10661, "You Don't Mess with the Zohan"),
#   (0.8813447662515579, 18, 'The Fifth Element'),
#   (0.8806054604387694, 559, 'Spider-Man 3'),
#   (0.8787933142539213, 291805, 'Now You See Me 2'),
#   (0.8763424150670012, 11615, 'The Life of David Gale'),
#   (0.8759131570690657, 818, 'Austin Powers in Goldmember'),
#   (0.8755925442518059, 11, 'Star Wars'),
#   (0.8749415700717762, 770, 'Gone with the Wind'),
#   (0.8737992054879069, 34106, "You Can't Take It With You"),
#   (0.8733564553849897, 297761, 'Suicide Squad'),
#   (0.8725539150797208, 1924, 'Superman'),
#   (0.8725004054222169, 769, 'GoodFellas'),
#   (0.8711202882299726, 4723, 'Southland Tales'),
#   (0.8693692307450225, 68721, 'Iron Man 3'),
#   (0.8692402895009951, 4982, 'American Gangster'),
#   (0.8685396689550592, 114150, 'Pitch Perfect'),
#   (0.8672833135432186, 686, 'Contact'),
#   (0.8667942029733768, 676, 'Pearl Harbor'),
#   (0.866471211559183, 24428, 'The Avengers'),
#   (0.8662220785315718, 1892, 'Return of the Jedi'),
#   (0.8659121235915047, 318846, 'The Big Short'),
#   (0.8640874209878586, 214756, 'Ted 2'),
#   (0.863980670194787, 640, 'Catch Me If You Can'),
#   (0.8638559825109946, 248774, 'Obvious Child'),
#   (0.8635874953464358, 597, 'Titanic'),
#   (0.863239571688746, 171274, 'Inherent Vice'),
#   (0.8616150430051156, 10138, 'Iron Man 2'),
#   (0.8613431612085639, 268920, 'Hot Pursuit'),
#   (0.8613298708867884, 19995, 'Avatar'),
#   (0.86097364888263, 2604, 'Born on the Fourth of July'),
#   (0.8609081188606497, 270487, 'Hail, Caesar!'),
#   (0.8608425283703389, 116741, 'The Internship'),
#   (0.8607520670711781, 44564, 'The Dilemma'),
#   (0.860186158976346, 1891, 'The Empire Strikes Back')],
#  'Superman Returns': [(0.7384418574014191, 1924, 'Superman'),
#   (0.7168376647215009, 155, 'The Dark Knight'),
#   (0.7145041184168809, 82695, 'Les Misérables'),
#   (0.7144011784667786, 80585, 'Rock of Ages'),
#   (0.7124897190436207, 8536, 'Superman II'),
#   (0.7113805496030126, 49026, 'The Dark Knight Rises'),
#   (0.7088976141751279, 9716, 'Everyone Says I Love You'),
#   (0.708860770620745, 209112, 'Batman v Superman: Dawn of Justice'),
#   (0.7087719868690207, 324668, 'Jason Bourne'),
#   (0.7077227865107819, 3083, 'Mr. Smith Goes to Washington'),
#   (0.7063248282529857, 18, 'The Fifth Element'),
#   (0.7062423823763428, 272, 'Batman Begins'),
#   (0.7047661395051918, 2976, 'Hairspray'),
#   (0.704187805885795, 559, 'Spider-Man 3'),
#   (0.7038547887083118, 13475, 'Star Trek'),
#   (0.7032362666768417, 39254, 'Real Steel'),
#   (0.7026721134382088, 11615, 'The Life of David Gale'),
#   (0.7014324791461387, 10661, "You Don't Mess with the Zohan"),
#   (0.7002934598491485, 68718, 'Django Unchained'),
#   (0.6999135208044163, 291805, 'Now You See Me 2'),
#   (0.6997224381136967, 68728, 'Oz: The Great and Powerful'),
#   (0.6996059936474763, 818, 'Austin Powers in Goldmember'),
#   (0.6991051026164946, 769, 'GoodFellas'),
#   (0.698818794791271, 106646, 'The Wolf of Wall Street'),
#   (0.6984917598194743, 297761, 'Suicide Squad'),
#   (0.69832193848743, 11, 'Star Wars'),
#   (0.6959421101621138, 34106, "You Can't Take It With You"),
#   (0.6953934279844947, 770, 'Gone with the Wind'),
#   (0.6952564444809926, 68721, 'Iron Man 3'),
#   (0.6940091719963517, 4723, 'Southland Tales'),
#   (0.6932173426952813, 24428, 'The Avengers'),
#   (0.6926942543879095, 10138, 'Iron Man 2'),
#   (0.691020920871386, 686, 'Contact'),
#   (0.6907502890581624, 4982, 'American Gangster'),
#   (0.6906795481235517, 248774, 'Obvious Child'),
#   (0.6905780663932259, 640, 'Catch Me If You Can'),
#   (0.6901531453232, 271110, 'Captain America: Civil War'),
#   (0.6899790054838767, 676, 'Pearl Harbor'),
#   (0.6893773866376565, 2604, 'Born on the Fourth of July'),
#   (0.6892147801264817, 318846, 'The Big Short'),
#   (0.6890032774608303, 1892, 'Return of the Jedi'),
#   (0.6888100955028084, 114150, 'Pitch Perfect'),
#   (0.6885111449796223, 597, 'Titanic'),
#   (0.688142678522136, 1891, 'The Empire Strikes Back'),
#   (0.6879006010511747, 19995, 'Avatar'),
#   (0.6877085522409047, 270487, 'Hail, Caesar!'),
#   (0.6876090945809794, 558, 'Spider-Man 2'),
#   (0.6868892225640687, 171274, 'Inherent Vice')],
#  'Quantum of Solace': [(0.7294069017974724, 82695, 'Les Misérables'),
#   (0.7233813094182678, 80585, 'Rock of Ages'),
#   (0.7232866651356132, 324668, 'Jason Bourne'),
#   (0.7204589946052081, 13475, 'Star Trek'),
#   (0.7198636687788045, 155, 'The Dark Knight'),
#   (0.7197626520806347, 9716, 'Everyone Says I Love You'),
#   (0.7188947376624958, 49026, 'The Dark Knight Rises'),
#   (0.7181405551933759, 2976, 'Hairspray'),
#   (0.7175492121617991, 39254, 'Real Steel'),
#   (0.717148040777058, 3083, 'Mr. Smith Goes to Washington'),
#   (0.7159460784932928, 272, 'Batman Begins'),
#   (0.7159370550959727, 18, 'The Fifth Element'),
#   (0.7145069621980311, 291805, 'Now You See Me 2'),
#   (0.7142847397073784, 68718, 'Django Unchained'),
#   (0.7142447636008582, 106646, 'The Wolf of Wall Street'),
#   (0.7137200934184128, 68728, 'Oz: The Great and Powerful'),
#   (0.7125134076315375, 559, 'Spider-Man 3'),
#   (0.7120668509607821, 10661, "You Don't Mess with the Zohan"),
#   (0.7119651769403761, 770, 'Gone with the Wind'),
#   (0.7119254751474262, 818, 'Austin Powers in Goldmember'),
#   (0.709969640105511, 209112, 'Batman v Superman: Dawn of Justice'),
#   (0.7092151543088158, 11615, 'The Life of David Gale'),
#   (0.7088555592176066, 11, 'Star Wars'),
#   (0.7078592341104847, 34106, "You Can't Take It With You"),
#   (0.7074021577643754, 4723, 'Southland Tales'),
#   (0.7073717987864592, 68721, 'Iron Man 3'),
#   (0.7073408156158381, 769, 'GoodFellas'),
#   (0.7056224168486835, 640, 'Catch Me If You Can'),
#   (0.7047128287838217, 297761, 'Suicide Squad'),
#   (0.7043966229245704, 1924, 'Superman'),
#   (0.7040114430558794, 4982, 'American Gangster'),
#   (0.7030698454503475, 686, 'Contact'),
#   (0.70276905591151, 597, 'Titanic'),
#   (0.7018607379222299, 1892, 'Return of the Jedi'),
#   (0.7015107594957924, 248774, 'Obvious Child'),
#   (0.7011158089581898, 268920, 'Hot Pursuit'),
#   (0.7011061546075692, 114150, 'Pitch Perfect'),
#   (0.7003743035362224, 676, 'Pearl Harbor'),
#   (0.6993104541463218, 2749, '15 Minutes'),
#   (0.6992956328070636, 11397, 'Not Another Teen Movie'),
#   (0.6989899109764565, 10138, 'Iron Man 2'),
#   (0.6988534309307566, 5503, 'The Fugitive'),
#   (0.69818315897098, 318846, 'The Big Short'),
#   (0.69778622099559, 752, 'V for Vendetta'),
#   (0.6976642514037104, 54138, 'Star Trek Into Darkness'),
#   (0.6975915827690343, 2604, 'Born on the Fourth of July'),
#   (0.6970399268184951, 116741, 'The Internship'),
#   (0.696937311296313, 214756, 'Ted 2')],
#  "Pirates of the Caribbean: Dead Man's Chest": [(0.8772413231357464,
#    285,
#    "Pirates of the Caribbean: At World's End"),
#   (0.8331085011529971,
#    22,
#    'Pirates of the Caribbean: The Curse of the Black Pearl'),
#   (0.8200487401154589, 82695, 'Les Misérables'),
#   (0.8189158922558504, 80585, 'Rock of Ages'),
#   (0.8164090238793208, 9716, 'Everyone Says I Love You'),
#   (0.8136967070122232, 13475, 'Star Trek'),
#   (0.8132002193794112, 324668, 'Jason Bourne'),
#   (0.8129263357853453, 3083, 'Mr. Smith Goes to Washington'),
#   (0.8107929100350894, 18, 'The Fifth Element'),
#   (0.8105210473513221, 39254, 'Real Steel'),
#   (0.8104602196542751, 49026, 'The Dark Knight Rises'),
#   (0.8098944480950047, 68728, 'Oz: The Great and Powerful'),
#   (0.8096470558877396, 155, 'The Dark Knight'),
#   (0.8071093705373452, 11, 'Star Wars'),
#   (0.807002254285213, 10661, "You Don't Mess with the Zohan"),
#   (0.8069017174275172, 2976, 'Hairspray'),
#   (0.8062257212180848, 68718, 'Django Unchained'),
#   (0.806173464201633, 272, 'Batman Begins'),
#   (0.8048464501585249, 559, 'Spider-Man 3'),
#   (0.8035427112648788, 106646, 'The Wolf of Wall Street'),
#   (0.8021424459056236, 11615, 'The Life of David Gale'),
#   (0.8019583880226947, 291805, 'Now You See Me 2'),
#   (0.8009991712966876, 209112, 'Batman v Superman: Dawn of Justice'),
#   (0.8005484679566773, 770, 'Gone with the Wind'),
#   (0.7990881035707139, 818, 'Austin Powers in Goldmember'),
#   (0.797771026161145, 34106, "You Can't Take It With You"),
#   (0.7973222045509774, 4723, 'Southland Tales'),
#   (0.7972588735143854, 1924, 'Superman'),
#   (0.797130163023625, 769, 'GoodFellas'),
#   (0.796706154492639, 1892, 'Return of the Jedi'),
#   (0.7946664141240852, 297761, 'Suicide Squad'),
#   (0.7946329808434568, 640, 'Catch Me If You Can'),
#   (0.7944750369459777, 114150, 'Pitch Perfect'),
#   (0.7944095212638312, 597, 'Titanic'),
#   (0.7941175195237, 4982, 'American Gangster'),
#   (0.7931783785066662, 686, 'Contact'),
#   (0.7927507974121455, 1891, 'The Empire Strikes Back'),
#   (0.7924298723920388, 68721, 'Iron Man 3'),
#   (0.7904508510631243, 318846, 'The Big Short'),
#   (0.7903579556525091, 248774, 'Obvious Child'),
#   (0.7902143272944118, 270487, 'Hail, Caesar!'),
#   (0.7901010888480599, 676, 'Pearl Harbor'),
#   (0.7892849749917423, 171274, 'Inherent Vice'),
#   (0.7892168262590821, 24428, 'The Avengers'),
#   (0.7882122055704334, 54138, 'Star Trek Into Darkness'),
#   (0.7872258883226532, 268920, 'Hot Pursuit'),
#   (0.7868457654162465, 10673, 'Wall Street'),
#   (0.7868391073975635, 10138, 'Iron Man 2')],
#  'The Lone Ranger': [(0.8206040660094669, 82695, 'Les Misérables'),
#   (0.8184630422170044, 80585, 'Rock of Ages'),
#   (0.8159105663283036, 3083, 'Mr. Smith Goes to Washington'),
#   (0.8157474595555139, 13475, 'Star Trek'),
#   (0.815128982215517, 324668, 'Jason Bourne'),
#   (0.8147915595303832, 9716, 'Everyone Says I Love You'),
#   (0.8113336410085925, 155, 'The Dark Knight'),
#   (0.8113235847517019, 2976, 'Hairspray'),
#   (0.8111864148685829, 39254, 'Real Steel'),
#   (0.8110184832054913, 49026, 'The Dark Knight Rises'),
#   (0.8068335684045096, 68728, 'Oz: The Great and Powerful'),
#   (0.8067386995029976, 68718, 'Django Unchained'),
#   (0.805649701389882, 10661, "You Don't Mess with the Zohan"),
#   (0.8054610715675795, 18, 'The Fifth Element'),
#   (0.8046999411655987, 106646, 'The Wolf of Wall Street'),
#   (0.8046520367494532, 11615, 'The Life of David Gale'),
#   (0.8045097851781889, 272, 'Batman Begins'),
#   (0.804227430468194, 559, 'Spider-Man 3'),
#   (0.8039176705726089, 770, 'Gone with the Wind'),
#   (0.8034756338558342, 209112, 'Batman v Superman: Dawn of Justice'),
#   (0.801790472975056, 11, 'Star Wars'),
#   (0.8003447184952313, 818, 'Austin Powers in Goldmember'),
#   (0.7999797516022935, 34106, "You Can't Take It With You"),
#   (0.7979793801273473, 769, 'GoodFellas'),
#   (0.797896326847937, 291805, 'Now You See Me 2'),
#   (0.7966775763520146, 68721, 'Iron Man 3'),
#   (0.7960656048516983, 114150, 'Pitch Perfect'),
#   (0.7957203500309952, 4723, 'Southland Tales'),
#   (0.7955207140671917, 4982, 'American Gangster'),
#   (0.79538222614063, 676, 'Pearl Harbor'),
#   (0.7939212498623657, 297761, 'Suicide Squad'),
#   (0.7932741799941855, 686, 'Contact'),
#   (0.7929963286990968, 1924, 'Superman'),
#   (0.7928689562634221, 597, 'Titanic'),
#   (0.7927197969680748, 1892, 'Return of the Jedi'),
#   (0.7917894330019137, 268920, 'Hot Pursuit'),
#   (0.7912531411061656, 640, 'Catch Me If You Can'),
#   (0.7889099633936999, 2604, 'Born on the Fourth of July'),
#   (0.7880941140353038, 10138, 'Iron Man 2'),
#   (0.7880802815632134, 2749, '15 Minutes'),
#   (0.7880121832951517, 820, 'JFK'),
#   (0.787881594565602, 44564, 'The Dilemma'),
#   (0.7878090263837562, 248774, 'Obvious Child'),
#   (0.7877132930005932, 171274, 'Inherent Vice'),
#   (0.7875678265746276, 3580, 'Changeling'),
#   (0.7875204357794415, 270487, 'Hail, Caesar!'),
#   (0.787468464929414, 675, 'Harry Potter and the Order of the Phoenix'),
#   (0.7871875598683521, 318846, 'The Big Short')],
#  'Man of Steel': [(0.8174160981543354,
#    209112,
#    'Batman v Superman: Dawn of Justice'),
#   (0.8112695344115918, 82695, 'Les Misérables'),
#   (0.8079993072039496, 80585, 'Rock of Ages'),
#   (0.807501595449274, 155, 'The Dark Knight'),
#   (0.8052478472286646, 272, 'Batman Begins'),
#   (0.8039343136776586, 3083, 'Mr. Smith Goes to Washington'),
#   (0.8028767332160233, 9716, 'Everyone Says I Love You'),
#   (0.801056248790808, 49026, 'The Dark Knight Rises'),
#   (0.8008251023754211, 1924, 'Superman'),
#   (0.8000794178272147, 13475, 'Star Trek'),
#   (0.7996510228765473, 324668, 'Jason Bourne'),
#   (0.7984910150645073, 18, 'The Fifth Element'),
#   (0.7984909645094956, 39254, 'Real Steel'),
#   (0.7959450995403939, 68728, 'Oz: The Great and Powerful'),
#   (0.7959168324743926, 297761, 'Suicide Squad'),
#   (0.7957942263314101, 2976, 'Hairspray'),
#   (0.7942611760554823, 559, 'Spider-Man 3'),
#   (0.7940696731701237, 68718, 'Django Unchained'),
#   (0.7940060558238743, 106646, 'The Wolf of Wall Street'),
#   (0.7932695391672215, 818, 'Austin Powers in Goldmember'),
#   (0.792452364914253, 291805, 'Now You See Me 2'),
#   (0.7923613733790906, 10661, "You Don't Mess with the Zohan"),
#   (0.7913895579877825, 11615, 'The Life of David Gale'),
#   (0.7897413365148138, 11, 'Star Wars'),
#   (0.7889992821234738, 770, 'Gone with the Wind'),
#   (0.788928366124702, 24428, 'The Avengers'),
#   (0.7887483797836714, 769, 'GoodFellas'),
#   (0.7878766783397491, 4982, 'American Gangster'),
#   (0.7866462548141979, 4723, 'Southland Tales'),
#   (0.785370927027697, 34106, "You Can't Take It With You"),
#   (0.7847403623352682, 68721, 'Iron Man 3'),
#   (0.7836988266646465, 114150, 'Pitch Perfect'),
#   (0.7825818066296641, 686, 'Contact'),
#   (0.7822240201212357, 10138, 'Iron Man 2'),
#   (0.7814964705586595, 248774, 'Obvious Child'),
#   (0.7804848012527785, 676, 'Pearl Harbor'),
#   (0.7803184960691566, 1892, 'Return of the Jedi'),
#   (0.7802089847847404, 640, 'Catch Me If You Can'),
#   (0.7799351431659234, 597, 'Titanic'),
#   (0.7794037670841356, 171274, 'Inherent Vice'),
#   (0.7793524636703961, 271110, 'Captain America: Civil War'),
#   (0.7793424976935819, 3580, 'Changeling'),
#   (0.7787310713067357, 318846, 'The Big Short'),
#   (0.7785868411556832, 1891, 'The Empire Strikes Back'),
#   (0.7784895057099711, 19995, 'Avatar'),
#   (0.7782565477251093, 268920, 'Hot Pursuit'),
#   (0.7769956279258702, 105, 'Back to the Future'),
#   (0.776127041275918, 675, 'Harry Potter and the Order of the Phoenix')],
#  'The Chronicles of Narnia: Prince Caspian': [(0.718592250061915,
#    411,
#    'The Chronicles of Narnia: The Lion, the Witch and the Wardrobe'),
#   (0.7078521332775941,
#    10140,
#    'The Chronicles of Narnia: The Voyage of the Dawn Treader'),
#   (0.6925879602924028, 82695, 'Les Misérables'),
#   (0.6900788758754302, 80585, 'Rock of Ages'),
#   (0.6896172944861718, 9716, 'Everyone Says I Love You'),
#   (0.6884444409198238, 324668, 'Jason Bourne'),
#   (0.6863943681449721, 3083, 'Mr. Smith Goes to Washington'),
#   (0.6860911823263339, 49026, 'The Dark Knight Rises'),
#   (0.6850853199176051, 18, 'The Fifth Element'),
#   (0.6839586758869528, 2976, 'Hairspray'),
#   (0.6838330534735152, 13475, 'Star Trek'),
#   (0.6836730630589876, 155, 'The Dark Knight'),
#   (0.6834307841684656, 272, 'Batman Begins'),
#   (0.6826599085030808, 39254, 'Real Steel'),
#   (0.6825329160002243, 11, 'Star Wars'),
#   (0.6817537818508823, 10661, "You Don't Mess with the Zohan"),
#   (0.6811006959327273, 68728, 'Oz: The Great and Powerful'),
#   (0.6807724111731493, 559, 'Spider-Man 3'),
#   (0.678897343468306, 818, 'Austin Powers in Goldmember'),
#   (0.6786451943460896, 770, 'Gone with the Wind'),
#   (0.6783568390255797, 106646, 'The Wolf of Wall Street'),
#   (0.6771986214799042, 68718, 'Django Unchained'),
#   (0.6767516142717285, 769, 'GoodFellas'),
#   (0.6765392028582333, 4723, 'Southland Tales'),
#   (0.6765045450459227, 11615, 'The Life of David Gale'),
#   (0.6756918195611943, 209112, 'Batman v Superman: Dawn of Justice'),
#   (0.6752303899163254, 291805, 'Now You See Me 2'),
#   (0.6737367808766022, 1892, 'Return of the Jedi'),
#   (0.6733590239595876, 34106, "You Can't Take It With You"),
#   (0.6718412982861655, 297761, 'Suicide Squad'),
#   (0.671039259866964, 1924, 'Superman'),
#   (0.6705885172578504, 114150, 'Pitch Perfect'),
#   (0.6704334508489703, 4982, 'American Gangster'),
#   (0.6703846634075495, 686, 'Contact'),
#   (0.669858615370988, 318846, 'The Big Short'),
#   (0.6696759773880395, 676, 'Pearl Harbor'),
#   (0.6680402571836248, 68721, 'Iron Man 3'),
#   (0.6679131444804953, 675, 'Harry Potter and the Order of the Phoenix'),
#   (0.6677720050361575, 2604, 'Born on the Fourth of July'),
#   (0.6675440027839363, 2749, '15 Minutes'),
#   (0.6674271816065206, 270487, 'Hail, Caesar!'),
#   (0.6667807887360064, 3580, 'Changeling'),
#   (0.6659191454239095, 171274, 'Inherent Vice'),
#   (0.6655668385942151, 116741, 'The Internship'),
#   (0.6654982637029542, 640, 'Catch Me If You Can'),
#   (0.6653823054297673, 597, 'Titanic'),
#   (0.6652823213449806, 19995, 'Avatar'),
#   (0.6652125140827597, 1891, 'The Empire Strikes Back')],
#  'The Avengers': [(0.8791625483578249, 80585, 'Rock of Ages'),
#   (0.8788635052492748, 82695, 'Les Misérables'),
#   (0.8767761122960082, 324668, 'Jason Bourne'),
#   (0.8766835670967008, 9716, 'Everyone Says I Love You'),
#   (0.8760186613370871, 49026, 'The Dark Knight Rises'),
#   (0.8737731872068832, 13475, 'Star Trek'),
#   (0.8737160129805808, 3083, 'Mr. Smith Goes to Washington'),
#   (0.871347373510293, 155, 'The Dark Knight'),
#   (0.8702807192715849, 39254, 'Real Steel'),
#   (0.8697236978254806, 2976, 'Hairspray'),
#   (0.8680472534904569, 106646, 'The Wolf of Wall Street'),
#   (0.8675293315587771, 559, 'Spider-Man 3'),
#   (0.8673232515312633, 18, 'The Fifth Element'),
#   (0.8665925484282497, 10661, "You Don't Mess with the Zohan"),
#   (0.866471211559183, 209112, 'Batman v Superman: Dawn of Justice'),
#   (0.8664079156015021, 68718, 'Django Unchained'),
#   (0.8661328988156523, 68728, 'Oz: The Great and Powerful'),
#   (0.864312831963655, 272, 'Batman Begins'),
#   (0.8634165698191703, 11, 'Star Wars'),
#   (0.8632410784576295, 11615, 'The Life of David Gale'),
#   (0.8631475607325392, 291805, 'Now You See Me 2'),
#   (0.8627867958662646, 68721, 'Iron Man 3'),
#   (0.8621590625340723, 770, 'Gone with the Wind'),
#   (0.8614819244919326, 769, 'GoodFellas'),
#   (0.861017005566262, 818, 'Austin Powers in Goldmember'),
#   (0.8595547077361917, 34106, "You Can't Take It With You"),
#   (0.8592658246994926, 1924, 'Superman'),
#   (0.8579254358638712, 10138, 'Iron Man 2'),
#   (0.8559421681854655, 4723, 'Southland Tales'),
#   (0.8554891201317867, 686, 'Contact'),
#   (0.8544593029006238, 4982, 'American Gangster'),
#   (0.8535441774358848, 640, 'Catch Me If You Can'),
#   (0.853472754901304, 271110, 'Captain America: Civil War'),
#   (0.8534647353799716, 297761, 'Suicide Squad'),
#   (0.8532406987447776, 114150, 'Pitch Perfect'),
#   (0.851906636914276, 676, 'Pearl Harbor'),
#   (0.8511584788012373, 1892, 'Return of the Jedi'),
#   (0.8492997192290267, 248774, 'Obvious Child'),
#   (0.848926593171935, 318846, 'The Big Short'),
#   (0.8474657223167402, 597, 'Titanic'),
#   (0.8473021538028477, 116741, 'The Internship'),
#   (0.847174024012871, 270487, 'Hail, Caesar!'),
#   (0.8468084917144807, 105, 'Back to the Future'),
#   (0.8467829809636435, 118340, 'Guardians of the Galaxy'),
#   (0.8466361953275539, 2604, 'Born on the Fourth of July'),
#   (0.8464944405992755, 1891, 'The Empire Strikes Back'),
#   (0.8460530672836012, 2749, '15 Minutes'),
#   (0.8460090117449985, 1726, 'Iron Man')],
#  'Pirates of the Caribbean: On Stranger Tides': [(0.8265624303533242,
#    82695,
#    'Les Misérables'),
#   (0.8188779274205197, 80585, 'Rock of Ages'),
#   (0.8159576437432102, 9716, 'Everyone Says I Love You'),
#   (0.8142220654969643, 324668, 'Jason Bourne'),
#   (0.8139580217258862, 3083, 'Mr. Smith Goes to Washington'),
#   (0.8131548109311191, 155, 'The Dark Knight'),
#   (0.8125481610502323, 18, 'The Fifth Element'),
#   (0.8123474829386497, 13475, 'Star Trek'),
#   (0.810821918019859, 49026, 'The Dark Knight Rises'),
#   (0.8103938752628266, 2976, 'Hairspray'),
#   (0.810260157856346,
#    22,
#    'Pirates of the Caribbean: The Curse of the Black Pearl'),
#   (0.809379362295007, 39254, 'Real Steel'),
#   (0.8083704570551383, 106646, 'The Wolf of Wall Street'),
#   (0.8067953073209927, 68728, 'Oz: The Great and Powerful'),
#   (0.8067516146587611, 272, 'Batman Begins'),
#   (0.8061564657314377, 10661, "You Don't Mess with the Zohan"),
#   (0.8056702897436264, 291805, 'Now You See Me 2'),
#   (0.8054472300132139, 68718, 'Django Unchained'),
#   (0.8052478072425827, 559, 'Spider-Man 3'),
#   (0.8050084148474237, 11, 'Star Wars'),
#   (0.8048555734627707, 11615, 'The Life of David Gale'),
#   (0.8045150420100636, 209112, 'Batman v Superman: Dawn of Justice'),
#   (0.8015551333360069, 770, 'Gone with the Wind'),
#   (0.8008117299198431, 769, 'GoodFellas'),
#   (0.799524244296066, 597, 'Titanic'),
#   (0.799519137697085, 34106, "You Can't Take It With You"),
#   (0.7989591093091795, 818, 'Austin Powers in Goldmember'),
#   (0.7978930269381712, 4723, 'Southland Tales'),
#   (0.7967750418778604, 1891, 'The Empire Strikes Back'),
#   (0.7964672635858866, 1892, 'Return of the Jedi'),
#   (0.7962746143760941, 4982, 'American Gangster'),
#   (0.7956405138167646, 114150, 'Pitch Perfect'),
#   (0.7950738269492027, 68721, 'Iron Man 3'),
#   (0.7943785823521818, 1924, 'Superman'),
#   (0.7940048827486155, 297761, 'Suicide Squad'),
#   (0.7927297119913864, 686, 'Contact'),
#   (0.7927003989588061, 640, 'Catch Me If You Can'),
#   (0.7914688042847138, 10673, 'Wall Street'),
#   (0.7912774197018925, 105, 'Back to the Future'),
#   (0.7910982059462244, 676, 'Pearl Harbor'),
#   (0.7904800506691005, 270487, 'Hail, Caesar!'),
#   (0.7903267956129296, 3580, 'Changeling'),
#   (0.7902464652179815, 11397, 'Not Another Teen Movie'),
#   (0.7894938186187461, 248774, 'Obvious Child'),
#   (0.7894659579818638, 2749, '15 Minutes'),
#   (0.7893527537894794, 10138, 'Iron Man 2'),
#   (0.7890503028162366, 19995, 'Avatar'),
#   (0.7889354722445061, 171274, 'Inherent Vice')],
#  'Men in Black 3': [(0.6607510305953461, 13475, 'Star Trek'),
#   (0.6604555287642985, 80585, 'Rock of Ages'),
#   (0.6595533723216259, 39254, 'Real Steel'),
#   (0.6575630633645967, 82695, 'Les Misérables'),
#   (0.6574977878005216, 105, 'Back to the Future'),
#   (0.6564076762356726, 18, 'The Fifth Element'),
#   (0.6562562840312158, 68728, 'Oz: The Great and Powerful'),
#   (0.6562530263856867, 324668, 'Jason Bourne'),
#   (0.656167551116907, 9716, 'Everyone Says I Love You'),
#   (0.6555451576130422, 3083, 'Mr. Smith Goes to Washington'),
#   (0.6535637786141762, 49026, 'The Dark Knight Rises'),
#   (0.6534337200251817, 106646, 'The Wolf of Wall Street'),
#   (0.6516624914702257, 155, 'The Dark Knight'),
#   (0.6515371585118563, 4723, 'Southland Tales'),
#   (0.6504213042331468, 818, 'Austin Powers in Goldmember'),
#   (0.6497686375893449, 2976, 'Hairspray'),
#   (0.6496978532439016, 272, 'Batman Begins'),
#   (0.6496649177713514, 68718, 'Django Unchained'),
#   (0.6493854270344099, 4982, 'American Gangster'),
#   (0.6486420135833455, 559, 'Spider-Man 3'),
#   (0.6476868886577829, 11615, 'The Life of David Gale'),
#   (0.647452089522835, 10661, "You Don't Mess with the Zohan"),
#   (0.647449319084474, 11, 'Star Wars'),
#   (0.6468401063134853, 209112, 'Batman v Superman: Dawn of Justice'),
#   (0.6450652649138451, 34106, "You Can't Take It With You"),
#   (0.6450627845671009, 770, 'Gone with the Wind'),
#   (0.644885544663495, 44564, 'The Dilemma'),
#   (0.6447862696181208, 291805, 'Now You See Me 2'),
#   (0.6437355349855817, 1892, 'Return of the Jedi'),
#   (0.6432246340909814, 686, 'Contact'),
#   (0.6431178024412482, 24428, 'The Avengers'),
#   (0.6429629287535084, 270487, 'Hail, Caesar!'),
#   (0.642766168314566, 5503, 'The Fugitive'),
#   (0.6426578665829721, 769, 'GoodFellas'),
#   (0.6425649661343439, 676, 'Pearl Harbor'),
#   (0.6423811441693417, 68721, 'Iron Man 3'),
#   (0.6420104337370125, 297761, 'Suicide Squad'),
#   (0.6416987391364501, 1883, 'Malcolm X'),
#   (0.6414555760501536, 1924, 'Superman'),
#   (0.6406025473819476, 19995, 'Avatar'),
#   (0.6401337927974825, 114150, 'Pitch Perfect'),
#   (0.6400342789179042, 10138, 'Iron Man 2'),
#   (0.6388407291745165, 82703, 'Mr. Peabody & Sherman'),
#   (0.6385640032391587, 127585, 'X-Men: Days of Future Past'),
#   (0.6385442144473215, 171274, 'Inherent Vice'),
#   (0.6384628948669945, 116741, 'The Internship'),
#   (0.638324092293958, 640, 'Catch Me If You Can'),
#   (0.6382957418914589, 318846, 'The Big Short')],
#  'The Hobbit: The Battle of the Five Armies': [(0.883916965993442,
#    57158,
#    'The Hobbit: The Desolation of Smaug'),
#   (0.860400977835823, 49051, 'The Hobbit: An Unexpected Journey'),
#   (0.7920165135400296,
#    120,
#    'The Lord of the Rings: The Fellowship of the Ring'),
#   (0.7860884129250957, 121, 'The Lord of the Rings: The Two Towers'),
#   (0.7852963215682094, 82695, 'Les Misérables'),
#   (0.7813968324949195, 122, 'The Lord of the Rings: The Return of the King'),
#   (0.779265263077856, 80585, 'Rock of Ages'),
#   (0.7763971112443198, 324668, 'Jason Bourne'),
#   (0.7761239967892047, 49026, 'The Dark Knight Rises'),
#   (0.7752347821969122, 9716, 'Everyone Says I Love You'),
#   (0.7746559788524944, 39254, 'Real Steel'),
#   (0.774589457672161, 13475, 'Star Trek'),
#   (0.7743549493913028, 3083, 'Mr. Smith Goes to Washington'),
#   (0.7737250239638646, 155, 'The Dark Knight'),
#   (0.773117385992588, 18, 'The Fifth Element'),
#   (0.7721738340388327, 10661, "You Don't Mess with the Zohan"),
#   (0.7720119638930296, 2976, 'Hairspray'),
#   (0.7704734140916365, 68728, 'Oz: The Great and Powerful'),
#   (0.7683396842186445, 272, 'Batman Begins'),
# ...
#   (0.6986194142777656, 291805, 'Now You See Me 2'),
#   (0.6984219835312151, 209112, 'Batman v Superman: Dawn of Justice'),
#   (0.6979147751707092, 769, 'GoodFellas'),
#   (0.6978761020284135, 818, 'Austin Powers in Goldmember'),
#   (0.6976933404294855, 770, 'Gone with the Wind'),
#   (0.6971276169187954, 4723, 'Southland Tales'),
#   (0.6969250679986759, 11, 'Star Wars'),
#   (0.6948928799878079, 34106, "You Can't Take It With You"),
#   (0.6947333696060511, 4982, 'American Gangster'),
#   (0.694382520812321, 1924, 'Superman'),
#   (0.6942269424295534, 686, 'Contact'),
#   (0.6935068537762423, 114150, 'Pitch Perfect'),
#   (0.6926416442562274, 297761, 'Suicide Squad'),
#   (0.6922759326215789, 318846, 'The Big Short'),
#   (0.6918873987458897, 1892, 'Return of the Jedi'),
#   (0.6917715007438394, 597, 'Titanic'),
#   (0.6901578805524174, 68721, 'Iron Man 3'),
#   (0.6899495328636884, 14560, 'Paul Blart: Mall Cop'),
#   (0.6893054942753476, 820, 'JFK'),
#   (0.6891755746518469, 24428, 'The Avengers'),
#   (0.6888493004255571, 2749, '15 Minutes'),
#   (0.688752534294826, 676, 'Pearl Harbor'),
#   (0.6881376699378018, 2604, 'Born on the Fourth of July'),
#   (0.6879565258772374, 116741, 'The Internship'),
#   (0.6875236973843952, 44564, 'The Dilemma'),
#   (0.6872142509580399, 248774, 'Obvious Child'),
#   (0.6867029707736669, 640, 'Catch Me If You Can'),
#   (0.686626004649068, 10138, 'Iron Man 2'),
#   (0.6865630827587245, 1891, 'The Empire Strikes Back')],
#  'Gamer': [(0.721706435207878, 82695, 'Les Misérables'),
#   (0.7166531211371323, 80585, 'Rock of Ages'),
#   (0.7153765085371743, 324668, 'Jason Bourne'),
#   (0.7148068957179257, 155, 'The Dark Knight'),
#   (0.7141601558298669, 9716, 'Everyone Says I Love You'),
#   (0.7133599668284748, 2976, 'Hairspray'),
#   (0.7123265017365024, 68718, 'Django Unchained'),
#   (0.7119245557610386, 13475, 'Star Trek'),
#   (0.7115193647938063, 39254, 'Real Steel'),
#   (0.7111756315475792, 3083, 'Mr. Smith Goes to Washington'),
#   (0.7107299813805213, 49026, 'The Dark Knight Rises'),
#   (0.7097378593936844, 106646, 'The Wolf of Wall Street'),
#   (0.7083441772907912, 291805, 'Now You See Me 2'),
#   (0.7080612968198728, 18, 'The Fifth Element'),
#   (0.7079410948805854, 272, 'Batman Begins'),
#   (0.7076360891865787, 68728, 'Oz: The Great and Powerful'),
#   (0.7067272090505484, 11, 'Star Wars'),
#   (0.7060138313546632, 559, 'Spider-Man 3'),
#   (0.7052713036433028, 209112, 'Batman v Superman: Dawn of Justice'),
#   (0.7045042218558007, 10661, "You Don't Mess with the Zohan"),
#   (0.7025817683823748, 818, 'Austin Powers in Goldmember'),
#   (0.7022728959300093, 770, 'Gone with the Wind'),
#   (0.7022512122713157, 11615, 'The Life of David Gale'),
#   (0.7017749457815118, 769, 'GoodFellas'),
#   (0.7011435711782065, 68721, 'Iron Man 3'),
#   (0.7009641544007881, 34106, "You Can't Take It With You"),
#   (0.7009334339095182, 4723, 'Southland Tales'),
#   (0.7001355330880539, 1924, 'Superman'),
#   (0.6987832240308886, 1892, 'Return of the Jedi'),
#   (0.6977928568210836, 597, 'Titanic'),
#   (0.6977163132851524, 4982, 'American Gangster'),
#   (0.696604741872147, 19995, 'Avatar'),
#   (0.6946983197956806, 676, 'Pearl Harbor'),
#   (0.6946561787330924, 686, 'Contact'),
#   (0.6944721654474416, 1891, 'The Empire Strikes Back'),
#   (0.6944123657176483, 318846, 'The Big Short'),
#   (0.6941189208288557, 10138, 'Iron Man 2'),
#   (0.6940696651772581, 114150, 'Pitch Perfect'),
#   (0.6939249717049718, 105, 'Back to the Future'),
#   (0.6939135646130731, 248774, 'Obvious Child'),
#   (0.6938605925235736, 297761, 'Suicide Squad'),
#   (0.693836953578124, 640, 'Catch Me If You Can'),
#   (0.6933766650855412, 2604, 'Born on the Fourth of July'),
#   (0.6930927652461063, 268920, 'Hot Pursuit'),
#   (0.6922691094786549, 24428, 'The Avengers'),
#   (0.6920765678079052, 44564, 'The Dilemma'),
#   (0.6919625219171874, 116741, 'The Internship'),
#   (0.6913895593742523, 214756, 'Ted 2')],
#  'Beautiful Creatures': [(0.820783995559551, 80585, 'Rock of Ages'),
#   (0.8206190224043785, 82695, 'Les Misérables'),
#   (0.8173818657436219, 9716, 'Everyone Says I Love You'),
#   (0.8145512731096063, 3083, 'Mr. Smith Goes to Washington'),
#   (0.814302006490083, 13475, 'Star Trek'),
#   (0.8129617859766356, 2976, 'Hairspray'),
#   (0.812752213593411, 324668, 'Jason Bourne'),
#   (0.8126414839034353, 49026, 'The Dark Knight Rises'),
#   (0.8119110433005576, 68718, 'Django Unchained'),
#   (0.8100790832524585, 39254, 'Real Steel'),
#   (0.8097822179776909, 68728, 'Oz: The Great and Powerful'),
#   (0.8089944629251825, 272, 'Batman Begins'),
#   (0.8087531647095185, 18, 'The Fifth Element'),
#   (0.8073867648864393, 155, 'The Dark Knight'),
#   (0.8067282027271732, 106646, 'The Wolf of Wall Street'),
#   (0.8065224500371918, 209112, 'Batman v Superman: Dawn of Justice'),
#   (0.8065185814370506, 770, 'Gone with the Wind'),
#   (0.8063613663329202, 10661, "You Don't Mess with the Zohan"),
#   (0.8056093379583571, 11615, 'The Life of David Gale'),
#   (0.8056027358139796, 291805, 'Now You See Me 2'),
#   (0.8040474082588233, 559, 'Spider-Man 3'),
#   (0.8027026664231235, 34106, "You Can't Take It With You"),
#   (0.8015787355620779, 769, 'GoodFellas'),
#   (0.8008766867313116, 11, 'Star Wars'),
#   (0.7992539965976504, 4723, 'Southland Tales'),
#   (0.7983406222859515, 4982, 'American Gangster'),
#   (0.7979614942897981, 818, 'Austin Powers in Goldmember'),
#   (0.7975190071118239, 686, 'Contact'),
#   (0.7961918811817646, 114150, 'Pitch Perfect'),
#   (0.7945746310884233, 318846, 'The Big Short'),
#   (0.7944170758573105, 268920, 'Hot Pursuit'),
#   (0.794137686382665, 297761, 'Suicide Squad'),
#   (0.794001173128121, 1892, 'Return of the Jedi'),
#   (0.7933854288047737, 1924, 'Superman'),
#   (0.792910857323012, 248774, 'Obvious Child'),
#   (0.792491238083959, 68721, 'Iron Man 3'),
#   (0.7922577890819925, 3059, 'Intolerance'),
#   (0.791926041453884, 676, 'Pearl Harbor'),
#   (0.791795085544188, 10138, 'Iron Man 2'),
#   (0.7915887535777566, 11397, 'Not Another Teen Movie'),
#   (0.7912475125223682, 270487, 'Hail, Caesar!'),
#   (0.7910081482653464, 597, 'Titanic'),
#   (0.7908438595953299, 24428, 'The Avengers'),
#   (0.7908080062730906, 171274, 'Inherent Vice'),
#   (0.7907593417897807, 640, 'Catch Me If You Can'),
#   (0.7891934451685843, 2749, '15 Minutes'),
#   (0.7888456247391998, 2604, 'Born on the Fourth of July'),
#   (0.7887276949641261, 116741, 'The Internship')],
#  'Death to Smoochy': [(0.5804474827613318,
#    3083,
#    'Mr. Smith Goes to Washington'),
#   (0.5768452956092287, 80585, 'Rock of Ages'),
#   (0.5764030655649779, 82695, 'Les Misérables'),
#   (0.5757656570147891, 9716, 'Everyone Says I Love You'),
#   (0.5753006185505005, 106646, 'The Wolf of Wall Street'),
#   (0.5742066925305203, 324668, 'Jason Bourne'),
#   (0.5739691013484309, 155, 'The Dark Knight'),
#   (0.5735960030775945, 769, 'GoodFellas'),
#   (0.573528401850634, 49026, 'The Dark Knight Rises'),
#   (0.5724578930633232, 272, 'Batman Begins'),
#   (0.5705923938724308, 18, 'The Fifth Element'),
#   (0.5705808803482926, 2976, 'Hairspray'),
#   (0.5701686903272288, 68718, 'Django Unchained'),
#   (0.5687965274812578, 13475, 'Star Trek'),
#   (0.5687863935473535, 39254, 'Real Steel'),
#   (0.5681555805320796, 10661, "You Don't Mess with the Zohan"),
#   (0.5681476763171937, 34106, "You Can't Take It With You"),
#   (0.5677261612602911, 209112, 'Batman v Superman: Dawn of Justice'),
#   (0.5671678528923129, 818, 'Austin Powers in Goldmember'),
#   (0.5671550158031923, 11, 'Star Wars'),
#   (0.5671158406555268, 11615, 'The Life of David Gale'),
#   (0.5670795588030696, 68728, 'Oz: The Great and Powerful'),
#   (0.5666474384925834, 4723, 'Southland Tales'),
#   (0.5662569957351283, 559, 'Spider-Man 3'),
#   (0.5650634828704283, 291805, 'Now You See Me 2'),
#   (0.5631876705604342, 4982, 'American Gangster'),
#   (0.5627504413420555, 770, 'Gone with the Wind'),
#   (0.5621111257374333, 5503, 'The Fugitive'),
#   (0.5613654251911833, 1892, 'Return of the Jedi'),
#   (0.5610845617240461, 11397, 'Not Another Teen Movie'),
#   (0.5607886249043368, 2749, '15 Minutes'),
#   (0.5605394015473392, 686, 'Contact'),
#   (0.5597760797053232, 597, 'Titanic'),
#   (0.5594546715001855, 676, 'Pearl Harbor'),
#   (0.5593610759655836, 114150, 'Pitch Perfect'),
#   (0.5592803050702122, 640, 'Catch Me If You Can'),
#   (0.5583106994574066, 297761, 'Suicide Squad'),
#   (0.5580792910671654, 2118, 'L.A. Confidential'),
#   (0.5576679848321396, 1585, "It's a Wonderful Life"),
#   (0.5576261088786638, 270487, 'Hail, Caesar!'),
#   (0.557563828693291, 1924, 'Superman'),
#   (0.5575286042835812, 318846, 'The Big Short'),
#   (0.5573191221045073, 68721, 'Iron Man 3'),
#   (0.5569352908760253, 116741, 'The Internship'),
#   (0.556795139167885, 268920, 'Hot Pursuit'),
#   (0.5567052708330908, 171274, 'Inherent Vice'),
#   (0.5566217162315532, 26390, "Brooklyn's Finest"),
#   (0.5561636233125585, 1891, 'The Empire Strikes Back')],
#  'Zoolander 2': [(0.8770518294189433, 82695, 'Les Misérables'),
#   (0.8741442319976802, 80585, 'Rock of Ages'),
#   (0.8723767233753984, 9716, 'Everyone Says I Love You'),
#   (0.8708338320838157, 324668, 'Jason Bourne'),
#   (0.8664665405337195, 2976, 'Hairspray'),
#   (0.8657979309064049, 18, 'The Fifth Element'),
#   (0.8656980389586933, 3083, 'Mr. Smith Goes to Washington'),
#   (0.8649781303419367, 13475, 'Star Trek'),
#   (0.8644869831641587, 155, 'The Dark Knight'),
#   (0.8643372939382774, 39254, 'Real Steel'),
#   (0.8637843783735631, 49026, 'The Dark Knight Rises'),
#   (0.8621988487692421, 68728, 'Oz: The Great and Powerful'),
#   (0.8615943926352125, 10661, "You Don't Mess with the Zohan"),
#   (0.8604730432463957, 106646, 'The Wolf of Wall Street'),
#   (0.8595293888300001, 272, 'Batman Begins'),
#   (0.8589253729439121, 68718, 'Django Unchained'),
#   (0.8571577061811965, 291805, 'Now You See Me 2'),
#   (0.8570000717863637, 559, 'Spider-Man 3'),
#   (0.8567633307005106, 209112, 'Batman v Superman: Dawn of Justice'),
#   (0.8565633152857829, 11, 'Star Wars'),
#   (0.8564155062313829, 818, 'Austin Powers in Goldmember'),
#   (0.8561447853273066, 11615, 'The Life of David Gale'),
#   (0.8548513254147532, 770, 'Gone with the Wind'),
#   (0.8532854275749377, 4723, 'Southland Tales'),
#   (0.8532198072835262, 9398, 'Zoolander'),
#   (0.8529044536783784, 769, 'GoodFellas'),
#   (0.8525076361111092, 34106, "You Can't Take It With You"),
#   (0.8483825244039779, 114150, 'Pitch Perfect'),
#   (0.8475739526567916, 4982, 'American Gangster'),
#   (0.846763289891439, 297761, 'Suicide Squad'),
#   (0.8465938976579624, 68721, 'Iron Man 3'),
#   (0.8459051873438251, 248774, 'Obvious Child'),
#   (0.8456676595840479, 1924, 'Superman'),
#   (0.844642929094052, 686, 'Contact'),
#   (0.8441923431539796, 640, 'Catch Me If You Can'),
#   (0.84390026285494, 676, 'Pearl Harbor'),
#   (0.8434874999821246, 1892, 'Return of the Jedi'),
#   (0.8434661468920727, 597, 'Titanic'),
#   (0.8426650427132238, 171274, 'Inherent Vice'),
#   (0.8421422882724213, 318846, 'The Big Short'),
#   (0.8419829112016387, 11397, 'Not Another Teen Movie'),
#   (0.8417252692823418, 116741, 'The Internship'),
#   (0.841348407955639, 10138, 'Iron Man 2'),
#   (0.8413327875858421, 268920, 'Hot Pursuit'),
#   (0.8412668299600704, 2749, '15 Minutes'),
#   (0.8401036520255241, 270487, 'Hail, Caesar!'),
#   (0.8399902980493132, 3580, 'Changeling'),
#   (0.8398601067959071, 24428, 'The Avengers')],
#  'The Big Bounce': [(0.7909564009143734, 82695, 'Les Misérables'),
#   (0.7899188164422146, 80585, 'Rock of Ages'),
#   (0.7875545502759317, 9716, 'Everyone Says I Love You'),
#   (0.7851514973840038, 3083, 'Mr. Smith Goes to Washington'),
#   (0.784933148598542, 155, 'The Dark Knight'),
#   (0.7846400753263126, 324668, 'Jason Bourne'),
#   (0.782711224522206, 13475, 'Star Trek'),
#   (0.781468896815706, 49026, 'The Dark Knight Rises'),
#   (0.7811676672318214, 39254, 'Real Steel'),
#   (0.7807368639396888, 2976, 'Hairspray'),
#   (0.7795605637451284, 18, 'The Fifth Element'),
#   (0.779248422469984, 272, 'Batman Begins'),
#   (0.7772099859450782, 106646, 'The Wolf of Wall Street'),
#   (0.7766849919206865, 68728, 'Oz: The Great and Powerful'),
#   (0.7759170031161942, 68718, 'Django Unchained'),
#   (0.7753292762830469, 10661, "You Don't Mess with the Zohan"),
#   (0.7740983682044145, 11, 'Star Wars'),
#   (0.773511280065816, 209112, 'Batman v Superman: Dawn of Justice'),
#   (0.7728073341836549, 11615, 'The Life of David Gale'),
#   (0.7726238305145382, 559, 'Spider-Man 3'),
#   (0.7723104557802536, 291805, 'Now You See Me 2'),
#   (0.7717487823358037, 4723, 'Southland Tales'),
#   (0.7710493507317315, 818, 'Austin Powers in Goldmember'),
#   (0.7709994833749828, 770, 'Gone with the Wind'),
#   (0.7709229037552306, 34106, "You Can't Take It With You"),
#   (0.7697471875238193, 769, 'GoodFellas'),
#   (0.7686716615021111, 686, 'Contact'),
#   (0.768666648311069, 114150, 'Pitch Perfect'),
#   (0.767085624623557, 676, 'Pearl Harbor'),
#   (0.7668630556131752, 68721, 'Iron Man 3'),
#   (0.7657168783760311, 4982, 'American Gangster'),
#   (0.7655249446151923, 297761, 'Suicide Squad'),
#   (0.765419898331004, 318846, 'The Big Short'),
#   (0.7648819530751232, 171274, 'Inherent Vice'),
#   (0.7639835083288259, 1892, 'Return of the Jedi'),
#   (0.7629618999701075, 3059, 'Intolerance'),
#   (0.7625713239599644, 1924, 'Superman'),
#   (0.7624644399495392, 19995, 'Avatar'),
#   (0.7620878968726678, 597, 'Titanic'),
#   (0.7620627658771838, 2749, '15 Minutes'),
#   (0.7620150073956, 116741, 'The Internship'),
#   (0.7619497912838705, 248774, 'Obvious Child'),
#   (0.761931511696158, 640, 'Catch Me If You Can'),
#   (0.761335842687584, 24428, 'The Avengers'),
#   (0.7610231828712094, 105, 'Back to the Future'),
#   (0.7601048976901067, 26390, "Brooklyn's Finest"),
#   (0.7593940753886698, 1883, 'Malcolm X'),
#   (0.7589810044695233, 10138, 'Iron Man 2')],
#  'What Planet Are You From?': [(0.5407042078206562, 82695, 'Les Misérables'),
#   (0.5384762297013302, 13475, 'Star Trek'),
#   (0.5377028374132433, 9716, 'Everyone Says I Love You'),
#   (0.5361018878523233, 80585, 'Rock of Ages'),
#   (0.5360710647478423, 324668, 'Jason Bourne'),
#   (0.5336110960243706, 3083, 'Mr. Smith Goes to Washington'),
#   (0.5333188591512702, 2976, 'Hairspray'),
#   (0.5327553717341074, 39254, 'Real Steel'),
#   (0.5327247922143277, 11, 'Star Wars'),
#   (0.532714749345865, 18, 'The Fifth Element'),
#   (0.5322432736525659, 106646, 'The Wolf of Wall Street'),
#   (0.5315460131762317, 155, 'The Dark Knight'),
#   (0.5311942250162947, 49026, 'The Dark Knight Rises'),
#   (0.5309354184461148, 559, 'Spider-Man 3'),
#   (0.5295566590108797, 10661, "You Don't Mess with the Zohan"),
#   (0.5293700897236553, 272, 'Batman Begins'),
#   (0.5292628964642648, 818, 'Austin Powers in Goldmember'),
#   (0.5291446260923747, 770, 'Gone with the Wind'),
#   (0.5290644438065533, 68728, 'Oz: The Great and Powerful'),
#   (0.5286371138036852, 291805, 'Now You See Me 2'),
#   (0.5285440698608265, 686, 'Contact'),
#   (0.528368231170187, 4723, 'Southland Tales'),
#   (0.5283065035429382, 19995, 'Avatar'),
#   (0.5283053145229795, 68718, 'Django Unchained'),
#   (0.5271498133947702, 209112, 'Batman v Superman: Dawn of Justice'),
#   (0.5260086420897273, 769, 'GoodFellas'),
#   (0.5255663695294417, 34106, "You Can't Take It With You"),
#   (0.5254754693640383, 68721, 'Iron Man 3'),
#   (0.5251616845512078, 11615, 'The Life of David Gale'),
#   (0.5237174757066644, 1924, 'Superman'),
#   (0.5230799578546503, 105, 'Back to the Future'),
#   (0.5227771965804106, 114150, 'Pitch Perfect'),
#   (0.5223530556946355, 1892, 'Return of the Jedi'),
#   (0.5221652980289658, 597, 'Titanic'),
#   (0.5218280266918897, 318846, 'The Big Short'),
#   (0.5214080528003591, 4982, 'American Gangster'),
#   (0.520594207221853, 10138, 'Iron Man 2'),
#   (0.520447493479555, 297761, 'Suicide Squad'),
#   (0.5203579831435563, 24428, 'The Avengers'),
#   (0.5202030231207591, 676, 'Pearl Harbor'),
#   (0.5199363785337275, 2604, 'Born on the Fourth of July'),
#   (0.519698818260406, 248774, 'Obvious Child'),
#   (0.519050262953468, 116741, 'The Internship'),
#   (0.5187481871290873, 270487, 'Hail, Caesar!'),
#   (0.5186102222061768, 2749, '15 Minutes'),
#   (0.5185774643342603, 1891, 'The Empire Strikes Back'),
#   (0.5183456250932713, 1585, "It's a Wonderful Life"),
#   (0.5182738602532544, 640, 'Catch Me If You Can')],
#  ...}

# %%
#reset the index in order to lookup the movie.
movies_df.reset_index(inplace=True)

# %%
movies_df.head()
# Out:
#    index      id  popularity                                      homepage  \
# 0      0   19995  150.437577                   http://www.avatarmovie.com/
# 1      1     285  139.082615  http://disney.go.com/disneypictures/pirates/
# 2      2  206647  107.376788   http://www.sonypictures.com/movies/spectre/
# 3      3   49026  112.312950            http://www.thedarkknightrises.com/
# 4      4   49529   43.926995          http://movies.disney.com/john-carter
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                               genres     budget     revenue  \
# 0  ['Action', 'Adventure', 'Fantasy', 'Science Fi...  237000000  2787965087
# 1                 ['Adventure', 'Fantasy', 'Action']  300000000   961000000
# 2                   ['Action', 'Adventure', 'Crime']  245000000   880674609
# 3           ['Action', 'Crime', 'Drama', 'Thriller']  250000000  1084939099
# 4         ['Action', 'Adventure', 'Science Fiction']  260000000   284139100
#
#                                                 cast  \
# 0  ['Sam Worthington', 'Zoe Saldana', 'Sigourney ...
# 1  ['Johnny Depp', 'Orlando Bloom', 'Keira Knight...
# 2  ['Daniel Craig', 'Christoph Waltz', 'Léa Seydo...
# 3  ['Christian Bale', 'Michael Caine', 'Gary Oldm...
# 4  ['Taylor Kitsch', 'Lynn Collins', 'Samantha Mo...
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                             keywords
# 0  ['culture clash', 'future', 'space war', 'spac...
# 1  ['ocean', 'drug abuse', 'exotic island', 'east...
# 2  ['spy', 'based on novel', 'secret agent', 'seq...
# 3  ['dc comics', 'crime fighter', 'terrorist', 's...
# 4  ['based on novel', 'mars', 'medallion', 'space...

# %%
#set the title_x become the index and index becomes column.
movies_df.set_index('original_title', inplace = True)
movies_df
# Out:
#                                           index      id  popularity  \
# original_title
# Avatar                                        0   19995  150.437577
# Pirates of the Caribbean: At World's End      1     285  139.082615
# Spectre                                       2  206647  107.376788
# The Dark Knight Rises                         3   49026  112.312950
# John Carter                                   4   49529   43.926995
# ...                                         ...     ...         ...
# El Mariachi                                4798    9367   14.269792
# Newlyweds                                  4799   72766    0.642552
# Signed, Sealed, Delivered                  4800  231617    1.444476
# Shanghai Calling                           4801  126186    0.857008
# My Date with Drew                          4802   25975    1.929883
#
#                                                                                    homepage  \
# original_title
# Avatar                                                          http://www.avatarmovie.com/
# Pirates of the Caribbean: At World's End       http://disney.go.com/disneypictures/pirates/
# Spectre                                         http://www.sonypictures.com/movies/spectre/
# The Dark Knight Rises                                    http://www.thedarkknightrises.com/
# John Carter                                            http://movies.disney.com/john-carter
# ...                                                                                     ...
# El Mariachi
# Newlyweds
# Signed, Sealed, Delivered                 http://www.hallmarkchannel.com/signedsealeddel...
# Shanghai Calling                                                http://shanghaicalling.com/
# My Date with Drew
#
#                                                                                      genres  \
# original_title
# Avatar                                    ['Action', 'Adventure', 'Fantasy', 'Science Fi...
# Pirates of the Caribbean: At World's End                 ['Adventure', 'Fantasy', 'Action']
# Spectre                                                    ['Action', 'Adventure', 'Crime']
# The Dark Knight Rises                              ['Action', 'Crime', 'Drama', 'Thriller']
# John Carter                                      ['Action', 'Adventure', 'Science Fiction']
# ...                                                                                     ...
# El Mariachi                                                 ['Action', 'Crime', 'Thriller']
# Newlyweds                                                             ['Comedy', 'Romance']
# Signed, Sealed, Delivered                        ['Comedy', 'Drama', 'Romance', 'TV Movie']
# Shanghai Calling                                                                         []
# My Date with Drew                                                           ['Documentary']
#
#                                              budget     revenue  \
# original_title
# Avatar                                    237000000  2787965087
# Pirates of the Caribbean: At World's End  300000000   961000000
# Spectre                                   245000000   880674609
# The Dark Knight Rises                     250000000  1084939099
# John Carter                               260000000   284139100
# ...                                             ...         ...
# El Mariachi                                  220000     2040920
# Newlyweds                                      9000           0
# Signed, Sealed, Delivered                         0           0
# Shanghai Calling                                  0           0
# My Date with Drew                                 0           0
#
#                                                                                        cast  \
# original_title
# Avatar                                    ['Sam Worthington', 'Zoe Saldana', 'Sigourney ...
# Pirates of the Caribbean: At World's End  ['Johnny Depp', 'Orlando Bloom', 'Keira Knight...
# Spectre                                   ['Daniel Craig', 'Christoph Waltz', 'Léa Seydo...
# The Dark Knight Rises                     ['Christian Bale', 'Michael Caine', 'Gary Oldm...
# John Carter                               ['Taylor Kitsch', 'Lynn Collins', 'Samantha Mo...
# ...                                                                                     ...
# El Mariachi                               ['Carlos Gallardo', 'Jaime de Hoyos', 'Peter M...
# Newlyweds                                 ['Edward Burns', 'Kerry Bishé', 'Marsha Dietle...
# Signed, Sealed, Delivered                 ['Eric Mabius', 'Kristin Booth', 'Crystal Lowe...
# Shanghai Calling                          ['Daniel Henney', 'Eliza Coupe', 'Bill Paxton'...
# My Date with Drew                         ['Drew Barrymore', 'Brian Herzlinger', 'Corey ...
#
#                                                                                    overview  \
# original_title
# Avatar                                    In the 22nd century, a paraplegic Marine is di...
# Pirates of the Caribbean: At World's End  Captain Barbossa, long believed to be dead, ha...
# Spectre                                   A cryptic message from Bond’s past sends him o...
# The Dark Knight Rises                     Following the death of District Attorney Harve...
# John Carter                               John Carter is a war-weary, former military ca...
# ...                                                                                     ...
# El Mariachi                               El Mariachi just wants to play his guitar and ...
# Newlyweds                                 A newlywed couple's honeymoon is upended by th...
# Signed, Sealed, Delivered                 "Signed, Sealed, Delivered" introduces a dedic...
# Shanghai Calling                          When ambitious New York attorney Sam is sent t...
# My Date with Drew                         Ever since the second grade when he first saw ...
#
#                                                                                     tagline  \
# original_title
# Avatar                                                          Enter the World of Pandora.
# Pirates of the Caribbean: At World's End     At the end of the world, the adventure begins.
# Spectre                                                               A Plan No One Escapes
# The Dark Knight Rises                                                       The Legend Ends
# John Carter                                            Lost in our world, found in another.
# ...                                                                                     ...
# El Mariachi                               He didn't come looking for trouble, but troubl...
# Newlyweds                                 A newlywed couple's honeymoon is upended by th...
# Signed, Sealed, Delivered
# Shanghai Calling                                                   A New Yorker in Shanghai
# My Date with Drew
#
#                                                                                    keywords
# original_title
# Avatar                                    ['culture clash', 'future', 'space war', 'spac...
# Pirates of the Caribbean: At World's End  ['ocean', 'drug abuse', 'exotic island', 'east...
# Spectre                                   ['spy', 'based on novel', 'secret agent', 'seq...
# The Dark Knight Rises                     ['dc comics', 'crime fighter', 'terrorist', 's...
# John Carter                               ['based on novel', 'mars', 'medallion', 'space...
# ...                                                                                     ...
# El Mariachi                               ['united states–mexico barrier', 'legs', 'arms...
# Newlyweds                                                                                []
# Signed, Sealed, Delivered                 ['date', 'love at first sight', 'narration', '...
# Shanghai Calling                                                                         []
# My Date with Drew                         ['obsession', 'camcorder', 'crush', 'dream girl']
#
# [4803 rows x 11 columns]

# %%
#this is where the movie names input is in lower case 
x = input()
if x in movies_df['index']:
    idx  = movies_df['index'].loc[x]
    idx
else:
    print('The movie you input does not exist or it is not included in the dataset!')
# Out:
# one piece
# The movie you input does not exist or it is not included in the dataset!

# %% [markdown]
# # Get recommendation based on cosine similarity

# %%
#The recommendation base on the cosine similarity.
#creating a get_recommendations function so that the recommendation is based on the cosine similarity.
def get_recommendations(title, n_recommendations=5, cosine_sim=cosine_similarities):
 
 if title in movies_df.index:
   idx = np.where(movies_df.index==title)[0][0]

# creating a Series with the similarity scores in descending order
   top_idx_list = pd.Series(cosine_sim[idx]).sort_values(ascending = False)[1:n_recommendations+1].index
 
   return list(movies_df.iloc[top_idx_list].index)
 else:
   print('The movie you input does not exist or it is not included in the dataset!')

# %%
#Get the top 5 similar movie based the overview, keywords, and genres.

overv_rec = list(get_recommendations(x, n_recommendations=5))
overv_rec
# Out:
# The movie you input does not exist or it is not included in the dataset!
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [57], in <cell line: 3>()
#       1 #Get the top 5 similar movie based the overview, keywords, and genres.
# ----> 3 overv_rec = list(get_recommendations(x, n_recommendations=5))
#       4 overv_rec
#
# TypeError: 'NoneType' object is not iterable

# %%
print('The top 5 recommended movies for ', x, movies_df['popularity'].loc[overv_rec])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [54], in <cell line: 1>()
# ----> 1 print('The top 5 recommended movies for ', x, movies_df['popularity'].loc[overv_rec])
#
# NameError: name 'overv_rec' is not defined

# %%
movies_df['Genres'].loc['avatar']
movies_df['Genres'].loc['jurassic world']
movies_df['Genres'].loc['15 minutes']
movies_df['Genres'].loc['the dark knight rises']
movies_df['Genres'].loc['jason bourne']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Genres'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [55], in <cell line: 1>()
# ----> 1 movies_df['Genres'].loc['avatar']
#       2 movies_df['Genres'].loc['jurassic world']
#       3 movies_df['Genres'].loc['15 minutes']
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'Genres'
